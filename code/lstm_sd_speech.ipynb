# %% [markdown]
# Long Short-Term Memory - Speaker Dependent

# %%
# import library
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random as rn

# %%
# clone dataset from github
# !git clone https://github.com/miftanurfarid/speech_emotion_recognition/
# Out:
# Cloning into 'speech_emotion_recognition'...
# remote: Enumerating objects: 6970, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 6970 (delta 66), reused 101 (delta 59), pack-reused 6861
# Receiving objects: 100% (6970/6970), 745.22 MiB | 25.60 MiB/s, done.
# Resolving deltas: 100% (386/386), done.
# Checking out files: 100% (5306/5306), done.

# %%
cd speech_emotion_recognition
# Out:
# /content/speech_emotion_recognition

# %%
np.random.seed(123)
rn.seed(123)
tf.random.set_seed(123)

# %%
# load feature data
data_path = 'data/speech/' # choose song or speech
X = np.load(data_path + 'x.npy')
y = np.load(data_path + 'y.npy')

# reshape x untuk lstm
X = X.reshape((X.shape[0], 1, X.shape[1]))

# if labels are not in integer, convert it, otherwise comment it
y = y.astype(int)

# %%
# split into train and test
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                             patience=10,
                                             restore_best_weights=True)
checkpointer = tf.keras.callbacks.ModelCheckpoint(
    filepath='/tmp/weights.hdf5', verbose=1, save_best_only=True)

# %%
# function to define model
def model_lstm():
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.BatchNormalization(axis=-1,
              input_shape=(x_train.shape[1], x_train.shape[2])))
    model.add(tf.keras.layers.LSTM(256, return_sequences=True))
    model.add(tf.keras.layers.LSTM(256, return_sequences=True))
    model.add(tf.keras.layers.LSTM(256, return_sequences=True))
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dropout(0.4))
    model.add(tf.keras.layers.Dense(8, activation='softmax'))

    # compile model: set loss, optimizer, metric
    model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                  optimizer=tf.keras.optimizers.Adam(),
                  metrics=['accuracy'])
    return model

# %%
# create the model
model = model_lstm()
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 1, 386)           1544
#  ormalization)
#
#  lstm (LSTM)                 (None, 1, 256)            658432
#
#  lstm_1 (LSTM)               (None, 1, 256)            525312
#
#  lstm_2 (LSTM)               (None, 1, 256)            525312
#
#  flatten (Flatten)           (None, 256)               0
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 8)                 2056
#
# =================================================================
# Total params: 1,712,656
# Trainable params: 1,711,884
# Non-trainable params: 772
# _________________________________________________________________
# None

# %%
# plot model
tf.keras.utils.plot_model(model,'lstm_model_sd_speech.pdf',show_shapes=True)

# %%
# train the model
hist = model.fit(x_train, 
                 y_train, 
                 epochs=100, 
                 shuffle=True, # mengacak data
                #  callbacks=earlystop, # akan berhenti saat konvergen meskipun belum sampai maksimal iterasi
                 validation_split=0.1, # 1% utk validasi
                 batch_size=16) # setiap 1 kali training ada 16 sampel
# Out:
# Epoch 1/100
# 73/73 [==============================] - 9s 47ms/step - loss: 1.8450 - accuracy: 0.2916 - val_loss: 1.9723 - val_accuracy: 0.2846
# Epoch 2/100
# 73/73 [==============================] - 2s 23ms/step - loss: 1.5213 - accuracy: 0.4220 - val_loss: 1.7719 - val_accuracy: 0.3769
# Epoch 3/100
# 73/73 [==============================] - 2s 22ms/step - loss: 1.2866 - accuracy: 0.5163 - val_loss: 1.5570 - val_accuracy: 0.4000
# Epoch 4/100
# 73/73 [==============================] - 2s 25ms/step - loss: 1.1158 - accuracy: 0.5720 - val_loss: 1.3274 - val_accuracy: 0.5231
# Epoch 5/100
# 73/73 [==============================] - 2s 26ms/step - loss: 0.9341 - accuracy: 0.6621 - val_loss: 1.1024 - val_accuracy: 0.5538
# Epoch 6/100
# 73/73 [==============================] - 2s 22ms/step - loss: 0.8139 - accuracy: 0.7015 - val_loss: 1.0931 - val_accuracy: 0.6000
# Epoch 7/100
# 73/73 [==============================] - 2s 22ms/step - loss: 0.6994 - accuracy: 0.7539 - val_loss: 0.9807 - val_accuracy: 0.6231
# Epoch 8/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.5665 - accuracy: 0.7976 - val_loss: 0.8295 - val_accuracy: 0.6923
# Epoch 9/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.5646 - accuracy: 0.7933 - val_loss: 0.8525 - val_accuracy: 0.7077
# Epoch 10/100
# 73/73 [==============================] - 2s 24ms/step - loss: 0.4551 - accuracy: 0.8456 - val_loss: 0.7440 - val_accuracy: 0.7077
# Epoch 11/100
# 73/73 [==============================] - 2s 26ms/step - loss: 0.3895 - accuracy: 0.8679 - val_loss: 0.6622 - val_accuracy: 0.7615
# Epoch 12/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.3620 - accuracy: 0.8808 - val_loss: 0.7288 - val_accuracy: 0.7000
# Epoch 13/100
# 73/73 [==============================] - 2s 24ms/step - loss: 0.3872 - accuracy: 0.8739 - val_loss: 0.7894 - val_accuracy: 0.6923
# Epoch 14/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.2896 - accuracy: 0.9057 - val_loss: 0.7585 - val_accuracy: 0.7077
# Epoch 15/100
# 73/73 [==============================] - 2s 26ms/step - loss: 0.2873 - accuracy: 0.9057 - val_loss: 0.9437 - val_accuracy: 0.6769
# Epoch 16/100
# 73/73 [==============================] - 2s 22ms/step - loss: 0.2687 - accuracy: 0.9099 - val_loss: 0.7169 - val_accuracy: 0.7077
# Epoch 17/100
# 73/73 [==============================] - 2s 26ms/step - loss: 0.2087 - accuracy: 0.9331 - val_loss: 0.7596 - val_accuracy: 0.7077
# Epoch 18/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.2482 - accuracy: 0.9185 - val_loss: 0.6713 - val_accuracy: 0.7615
# Epoch 19/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.2371 - accuracy: 0.9151 - val_loss: 0.7762 - val_accuracy: 0.7231
# Epoch 20/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.1662 - accuracy: 0.9417 - val_loss: 0.6716 - val_accuracy: 0.7462
# Epoch 21/100
# 73/73 [==============================] - 2s 24ms/step - loss: 0.1725 - accuracy: 0.9434 - val_loss: 0.6656 - val_accuracy: 0.7385
# Epoch 22/100
# 73/73 [==============================] - 2s 26ms/step - loss: 0.1644 - accuracy: 0.9434 - val_loss: 0.6866 - val_accuracy: 0.7615
# Epoch 23/100
# 73/73 [==============================] - 2s 26ms/step - loss: 0.1640 - accuracy: 0.9417 - val_loss: 0.8344 - val_accuracy: 0.7385
# Epoch 24/100
# 73/73 [==============================] - 2s 27ms/step - loss: 0.1954 - accuracy: 0.9365 - val_loss: 0.6550 - val_accuracy: 0.7462
# Epoch 25/100
# 73/73 [==============================] - 2s 25ms/step - loss: 0.1503 - accuracy: 0.9511 - val_loss: 0.7325 - val_accuracy: 0.7846
# Epoch 26/100
# 73/73 [==============================] - 2s 27ms/step - loss: 0.1342 - accuracy: 0.9597 - val_loss: 0.6943 - val_accuracy: 0.7462
# Epoch 27/100
# 73/73 [==============================] - 2s 30ms/step - loss: 0.1554 - accuracy: 0.9485 - val_loss: 0.6583 - val_accuracy: 0.7846
# Epoch 28/100
# 73/73 [==============================] - 2s 28ms/step - loss: 0.1405 - accuracy: 0.9571 - val_loss: 0.6764 - val_accuracy: 0.7769
# Epoch 29/100
# 73/73 [==============================] - 2s 26ms/step - loss: 0.1361 - accuracy: 0.9580 - val_loss: 0.6557 - val_accuracy: 0.7923
# Epoch 30/100
# 73/73 [==============================] - 2s 26ms/step - loss: 0.1142 - accuracy: 0.9666 - val_loss: 0.6106 - val_accuracy: 0.7923
# Epoch 31/100
# 73/73 [==============================] - 2s 32ms/step - loss: 0.0844 - accuracy: 0.9683 - val_loss: 0.6327 - val_accuracy: 0.7846
# Epoch 32/100
# 73/73 [==============================] - 2s 25ms/step - loss: 0.1182 - accuracy: 0.9588 - val_loss: 0.5252 - val_accuracy: 0.8154
# Epoch 33/100
# 73/73 [==============================] - 2s 28ms/step - loss: 0.0802 - accuracy: 0.9751 - val_loss: 0.6699 - val_accuracy: 0.7769
# Epoch 34/100
# 73/73 [==============================] - 2s 28ms/step - loss: 0.1377 - accuracy: 0.9503 - val_loss: 0.7565 - val_accuracy: 0.7692
# Epoch 35/100
# 73/73 [==============================] - 2s 24ms/step - loss: 0.0840 - accuracy: 0.9768 - val_loss: 0.8305 - val_accuracy: 0.7538
# Epoch 36/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.1096 - accuracy: 0.9605 - val_loss: 0.7487 - val_accuracy: 0.7615
# Epoch 37/100
# 73/73 [==============================] - 2s 25ms/step - loss: 0.1131 - accuracy: 0.9631 - val_loss: 0.6137 - val_accuracy: 0.8000
# Epoch 38/100
# 73/73 [==============================] - 2s 26ms/step - loss: 0.0844 - accuracy: 0.9700 - val_loss: 0.5762 - val_accuracy: 0.8308
# Epoch 39/100
# 73/73 [==============================] - 2s 26ms/step - loss: 0.0931 - accuracy: 0.9691 - val_loss: 0.7632 - val_accuracy: 0.7769
# Epoch 40/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.0984 - accuracy: 0.9666 - val_loss: 0.6179 - val_accuracy: 0.7923
# Epoch 41/100
# 73/73 [==============================] - 2s 26ms/step - loss: 0.0859 - accuracy: 0.9734 - val_loss: 0.7437 - val_accuracy: 0.7769
# Epoch 42/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.0885 - accuracy: 0.9691 - val_loss: 0.8328 - val_accuracy: 0.7385
# Epoch 43/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.0684 - accuracy: 0.9786 - val_loss: 0.7233 - val_accuracy: 0.7615
# Epoch 44/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.0721 - accuracy: 0.9743 - val_loss: 0.7570 - val_accuracy: 0.7846
# Epoch 45/100
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0528 - accuracy: 0.9871 - val_loss: 0.5842 - val_accuracy: 0.8308
# Epoch 46/100
# 73/73 [==============================] - 2s 25ms/step - loss: 0.0891 - accuracy: 0.9743 - val_loss: 1.0170 - val_accuracy: 0.7462
# Epoch 47/100
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0711 - accuracy: 0.9786 - val_loss: 0.8778 - val_accuracy: 0.7692
# Epoch 48/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.0528 - accuracy: 0.9803 - val_loss: 0.6822 - val_accuracy: 0.8000
# Epoch 49/100
# 73/73 [==============================] - 2s 32ms/step - loss: 0.1077 - accuracy: 0.9700 - val_loss: 0.8887 - val_accuracy: 0.7846
# Epoch 50/100
# 73/73 [==============================] - 2s 26ms/step - loss: 0.0655 - accuracy: 0.9803 - val_loss: 0.7466 - val_accuracy: 0.7769
# Epoch 51/100
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0503 - accuracy: 0.9846 - val_loss: 0.8691 - val_accuracy: 0.7769
# Epoch 52/100
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0683 - accuracy: 0.9786 - val_loss: 0.7682 - val_accuracy: 0.7846
# Epoch 53/100
# 73/73 [==============================] - 2s 27ms/step - loss: 0.0741 - accuracy: 0.9760 - val_loss: 0.6955 - val_accuracy: 0.8154
# Epoch 54/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.0676 - accuracy: 0.9734 - val_loss: 0.6334 - val_accuracy: 0.8231
# Epoch 55/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.0795 - accuracy: 0.9751 - val_loss: 0.5840 - val_accuracy: 0.8154
# Epoch 56/100
# 73/73 [==============================] - 2s 25ms/step - loss: 0.0601 - accuracy: 0.9820 - val_loss: 0.7098 - val_accuracy: 0.8000
# Epoch 57/100
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0802 - accuracy: 0.9743 - val_loss: 0.8378 - val_accuracy: 0.7846
# Epoch 58/100
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0737 - accuracy: 0.9726 - val_loss: 0.7192 - val_accuracy: 0.8077
# Epoch 59/100
# 73/73 [==============================] - 2s 24ms/step - loss: 0.0547 - accuracy: 0.9828 - val_loss: 0.5887 - val_accuracy: 0.8308
# Epoch 60/100
# 73/73 [==============================] - 2s 28ms/step - loss: 0.0514 - accuracy: 0.9846 - val_loss: 0.7372 - val_accuracy: 0.8154
# Epoch 61/100
# 73/73 [==============================] - 2s 26ms/step - loss: 0.0512 - accuracy: 0.9854 - val_loss: 0.6814 - val_accuracy: 0.8000
# Epoch 62/100
# 73/73 [==============================] - 2s 27ms/step - loss: 0.0559 - accuracy: 0.9786 - val_loss: 0.6817 - val_accuracy: 0.8077
# Epoch 63/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.0729 - accuracy: 0.9811 - val_loss: 0.6649 - val_accuracy: 0.7769
# Epoch 64/100
# 73/73 [==============================] - 2s 28ms/step - loss: 0.0503 - accuracy: 0.9837 - val_loss: 0.5721 - val_accuracy: 0.8077
# Epoch 65/100
# 73/73 [==============================] - 2s 24ms/step - loss: 0.0849 - accuracy: 0.9786 - val_loss: 0.6210 - val_accuracy: 0.7923
# Epoch 66/100
# 73/73 [==============================] - 2s 27ms/step - loss: 0.0512 - accuracy: 0.9828 - val_loss: 0.5661 - val_accuracy: 0.8308
# Epoch 67/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.0453 - accuracy: 0.9846 - val_loss: 0.6733 - val_accuracy: 0.8000
# Epoch 68/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.0442 - accuracy: 0.9863 - val_loss: 0.5686 - val_accuracy: 0.7923
# Epoch 69/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.0525 - accuracy: 0.9837 - val_loss: 0.7204 - val_accuracy: 0.7923
# Epoch 70/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.0393 - accuracy: 0.9914 - val_loss: 0.7756 - val_accuracy: 0.7846
# Epoch 71/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.0394 - accuracy: 0.9846 - val_loss: 0.6447 - val_accuracy: 0.8077
# Epoch 72/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.0943 - accuracy: 0.9717 - val_loss: 0.7732 - val_accuracy: 0.7923
# Epoch 73/100
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0478 - accuracy: 0.9786 - val_loss: 0.9101 - val_accuracy: 0.7846
# Epoch 74/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.0448 - accuracy: 0.9871 - val_loss: 0.7879 - val_accuracy: 0.8077
# Epoch 75/100
# 73/73 [==============================] - 2s 26ms/step - loss: 0.0761 - accuracy: 0.9786 - val_loss: 0.7065 - val_accuracy: 0.8231
# Epoch 76/100
# 73/73 [==============================] - 2s 28ms/step - loss: 0.0673 - accuracy: 0.9777 - val_loss: 0.6848 - val_accuracy: 0.8231
# Epoch 77/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.0731 - accuracy: 0.9811 - val_loss: 0.7888 - val_accuracy: 0.7769
# Epoch 78/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.0526 - accuracy: 0.9820 - val_loss: 0.8259 - val_accuracy: 0.7769
# Epoch 79/100
# 73/73 [==============================] - 2s 26ms/step - loss: 0.0492 - accuracy: 0.9846 - val_loss: 0.7612 - val_accuracy: 0.7769
# Epoch 80/100
# 73/73 [==============================] - 2s 24ms/step - loss: 0.0402 - accuracy: 0.9871 - val_loss: 0.8353 - val_accuracy: 0.7923
# Epoch 81/100
# 73/73 [==============================] - 2s 31ms/step - loss: 0.0298 - accuracy: 0.9871 - val_loss: 0.7516 - val_accuracy: 0.8000
# Epoch 82/100
# 73/73 [==============================] - 2s 27ms/step - loss: 0.0393 - accuracy: 0.9837 - val_loss: 0.7542 - val_accuracy: 0.7923
# Epoch 83/100
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0336 - accuracy: 0.9889 - val_loss: 0.7806 - val_accuracy: 0.7615
# Epoch 84/100
# 73/73 [==============================] - 2s 24ms/step - loss: 0.0680 - accuracy: 0.9760 - val_loss: 0.8577 - val_accuracy: 0.7615
# Epoch 85/100
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0497 - accuracy: 0.9889 - val_loss: 0.6671 - val_accuracy: 0.8077
# Epoch 86/100
# 73/73 [==============================] - 2s 30ms/step - loss: 0.0272 - accuracy: 0.9897 - val_loss: 0.7350 - val_accuracy: 0.8000
# Epoch 87/100
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0552 - accuracy: 0.9794 - val_loss: 0.8351 - val_accuracy: 0.7769
# Epoch 88/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.0341 - accuracy: 0.9897 - val_loss: 0.8263 - val_accuracy: 0.7769
# Epoch 89/100
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0505 - accuracy: 0.9837 - val_loss: 0.7270 - val_accuracy: 0.8000
# Epoch 90/100
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0475 - accuracy: 0.9863 - val_loss: 0.7964 - val_accuracy: 0.8077
# Epoch 91/100
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0386 - accuracy: 0.9871 - val_loss: 0.8620 - val_accuracy: 0.7923
# Epoch 92/100
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0471 - accuracy: 0.9863 - val_loss: 0.9084 - val_accuracy: 0.7538
# Epoch 93/100
# 73/73 [==============================] - 2s 25ms/step - loss: 0.0407 - accuracy: 0.9837 - val_loss: 0.9719 - val_accuracy: 0.7692
# Epoch 94/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.0694 - accuracy: 0.9828 - val_loss: 0.7712 - val_accuracy: 0.7769
# Epoch 95/100
# 73/73 [==============================] - 2s 29ms/step - loss: 0.0644 - accuracy: 0.9794 - val_loss: 0.7843 - val_accuracy: 0.7615
# Epoch 96/100
# 73/73 [==============================] - 2s 25ms/step - loss: 0.0573 - accuracy: 0.9837 - val_loss: 0.7107 - val_accuracy: 0.7923
# Epoch 97/100
# 73/73 [==============================] - 2s 24ms/step - loss: 0.0517 - accuracy: 0.9854 - val_loss: 0.7276 - val_accuracy: 0.7769
# Epoch 98/100
# 73/73 [==============================] - 2s 28ms/step - loss: 0.0359 - accuracy: 0.9889 - val_loss: 0.6521 - val_accuracy: 0.7923
# Epoch 99/100
# 73/73 [==============================] - 2s 24ms/step - loss: 0.0485 - accuracy: 0.9880 - val_loss: 0.7682 - val_accuracy: 0.7846
# Epoch 100/100
# 73/73 [==============================] - 2s 23ms/step - loss: 0.0485 - accuracy: 0.9820 - val_loss: 0.7922 - val_accuracy: 0.7923

# %%
evaluate = model.evaluate(x_test, y_test, batch_size=16)

print("Loss={:.6f}, Accuracy={:.6f}".format(evaluate[0],evaluate[1]))
# Out:
# 9/9 [==============================] - 1s 6ms/step - loss: 1.0871 - accuracy: 0.7431
# Loss=1.087127, Accuracy=0.743056

# %%
# plot accuracy
plt.figure()
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.grid()
plt.legend(['Training', 'Validation'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('LSTM Model')
plt.savefig('lstm_accuracy_sd_speech.svg')

# %%
# make prediction for confusion_matrix
import os
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
predict = model.predict(x_test, batch_size=16)
emotions=['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprise']

# predicted emotions from the test set
y_pred = np.argmax(predict, 1)
predicted_emo = []
for i in range(0,y_test.shape[0]):
    emo = emotions[y_pred[i]]
    predicted_emo.append(emo)

# get actual emotion
actual_emo = []
y_true = y_test
for i in range(0,y_test.shape[0]):
    emo = emotions[y_true[i]]
    actual_emo.append(emo)

# generate the confusion matrix
cm = confusion_matrix(actual_emo, predicted_emo)
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

index = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprise']
columns = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprise']
cm_df = pd.DataFrame(cm, index, columns)
plt.figure(figsize=(10, 6))
plt.title('Confusion Matrix of LSTM')
sns.heatmap(cm_df, annot=True)
plt.savefig('lstm_cm_sd_speech.svg')

# %%
# print unweighted average recall
print("UAR: ", cm.trace()/cm.shape[0])
# Out:
# UAR:  0.7294908930938342
