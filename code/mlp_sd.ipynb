# %% [markdown]
# Multi Layer Perceptron - Speaker Dependent

# %%
# import library
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random as rn

# %%
# clone dataset from github
# !git clone https://github.com/miftanurfarid/speech_emotion_recognition/
# Out:
# Cloning into 'speech_emotion_recognition'...
# remote: Enumerating objects: 6987, done.
# remote: Counting objects: 100% (126/126), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 6987 (delta 77), reused 116 (delta 67), pack-reused 6861
# Receiving objects: 100% (6987/6987), 745.63 MiB | 25.38 MiB/s, done.
# Resolving deltas: 100% (397/397), done.
# Checking out files: 100% (5322/5322), done.

# %%
cd speech_emotion_recognition
# Out:
# /content/speech_emotion_recognition

# %%
np.random.seed(123)
rn.seed(123)
tf.random.set_seed(123)

# %%
# load feature data
data_path = 'data/song/' # choose song or speech
X = np.load(data_path + 'x.npy')
y = np.load(data_path + 'y.npy')

# %%
# split into train and test
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                             patience=10,
                                             restore_best_weights=True)

checkpointer = tf.keras.callbacks.ModelCheckpoint(
    filepath='/tmp/weights.hdf5', verbose=1, save_best_only=True)

# %%
# function to build model MLP/ FCN = Full connected neural network
def model_dense():
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.BatchNormalization(axis=-1,
              input_shape=(x_train.shape[1:])))
    model.add(tf.keras.layers.Dense(256, activation='relu'))
    model.add(tf.keras.layers.Dense(256, activation='relu'))
    model.add(tf.keras.layers.Dense(256, activation='relu'))
    model.add(tf.keras.layers.Dropout(0.4))
    model.add(tf.keras.layers.Dense(6, activation='softmax'))

    # compile model: set loss, optimizer, metric
    model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                  optimizer=tf.keras.optimizers.Adam(),
                  metrics=['accuracy'])
    return model

# %%
# create the model
model = model_dense()
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 386)              1544
#  ormalization)
#
#  dense (Dense)               (None, 256)               99072
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_3 (Dense)             (None, 6)                 1542
#
# =================================================================
# Total params: 233,742
# Trainable params: 232,970
# Non-trainable params: 772
# _________________________________________________________________
# None

# %%
# plot model
tf.keras.utils.plot_model(model,'mlp_model_sd.pdf',show_shapes=True)

# %%
# train the model
hist = model.fit(x_train, # fitur 
                 y_train, # label
                 epochs=100, # banyaknya iterasi
                 shuffle=True,
                 #callbacks=earlystop,
                 validation_split=0.1,
                 batch_size=16)
# Out:
# Epoch 1/100
# 52/52 [==============================] - 1s 9ms/step - loss: 1.1836 - accuracy: 0.5385 - val_loss: 5.3928 - val_accuracy: 0.2857
# Epoch 2/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.7043 - accuracy: 0.7375 - val_loss: 1.5127 - val_accuracy: 0.5714
# Epoch 3/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.5039 - accuracy: 0.8181 - val_loss: 1.0838 - val_accuracy: 0.6154
# Epoch 4/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.4583 - accuracy: 0.8278 - val_loss: 0.7273 - val_accuracy: 0.7582
# Epoch 5/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.3838 - accuracy: 0.8547 - val_loss: 0.5136 - val_accuracy: 0.8242
# Epoch 6/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.3071 - accuracy: 0.8803 - val_loss: 0.4256 - val_accuracy: 0.8571
# Epoch 7/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.3059 - accuracy: 0.8852 - val_loss: 0.3324 - val_accuracy: 0.9011
# Epoch 8/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2402 - accuracy: 0.9084 - val_loss: 0.3964 - val_accuracy: 0.8132
# Epoch 9/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2567 - accuracy: 0.9084 - val_loss: 0.6929 - val_accuracy: 0.7582
# Epoch 10/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2005 - accuracy: 0.9353 - val_loss: 0.3851 - val_accuracy: 0.8242
# Epoch 11/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1325 - accuracy: 0.9512 - val_loss: 0.2008 - val_accuracy: 0.9341
# Epoch 12/100
# 52/52 [==============================] - 0s 7ms/step - loss: 0.1955 - accuracy: 0.9292 - val_loss: 0.3712 - val_accuracy: 0.8462
# Epoch 13/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2252 - accuracy: 0.9170 - val_loss: 0.2824 - val_accuracy: 0.9341
# Epoch 14/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1189 - accuracy: 0.9548 - val_loss: 0.1926 - val_accuracy: 0.9011
# Epoch 15/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1492 - accuracy: 0.9499 - val_loss: 0.2957 - val_accuracy: 0.9011
# Epoch 16/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1779 - accuracy: 0.9487 - val_loss: 0.1124 - val_accuracy: 0.9670
# Epoch 17/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1961 - accuracy: 0.9402 - val_loss: 0.2128 - val_accuracy: 0.9121
# Epoch 18/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1513 - accuracy: 0.9499 - val_loss: 0.2304 - val_accuracy: 0.9231
# Epoch 19/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0874 - accuracy: 0.9719 - val_loss: 0.1003 - val_accuracy: 0.9560
# Epoch 20/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1105 - accuracy: 0.9646 - val_loss: 0.2214 - val_accuracy: 0.9560
# Epoch 21/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1782 - accuracy: 0.9341 - val_loss: 0.2766 - val_accuracy: 0.9121
# Epoch 22/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2043 - accuracy: 0.9267 - val_loss: 0.2053 - val_accuracy: 0.9341
# Epoch 23/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1855 - accuracy: 0.9438 - val_loss: 0.3578 - val_accuracy: 0.8791
# Epoch 24/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1084 - accuracy: 0.9548 - val_loss: 0.2246 - val_accuracy: 0.9451
# Epoch 25/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1218 - accuracy: 0.9695 - val_loss: 0.2194 - val_accuracy: 0.9451
# Epoch 26/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1654 - accuracy: 0.9609 - val_loss: 0.1952 - val_accuracy: 0.9341
# Epoch 27/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0949 - accuracy: 0.9695 - val_loss: 0.2753 - val_accuracy: 0.9560
# Epoch 28/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1154 - accuracy: 0.9573 - val_loss: 0.1787 - val_accuracy: 0.9560
# Epoch 29/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0957 - accuracy: 0.9670 - val_loss: 0.3531 - val_accuracy: 0.9231
# Epoch 30/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0992 - accuracy: 0.9670 - val_loss: 0.2121 - val_accuracy: 0.9451
# Epoch 31/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0811 - accuracy: 0.9756 - val_loss: 0.3256 - val_accuracy: 0.9231
# Epoch 32/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1072 - accuracy: 0.9658 - val_loss: 0.2201 - val_accuracy: 0.9451
# Epoch 33/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1166 - accuracy: 0.9670 - val_loss: 0.1793 - val_accuracy: 0.9560
# Epoch 34/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1033 - accuracy: 0.9658 - val_loss: 0.3424 - val_accuracy: 0.9231
# Epoch 35/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1095 - accuracy: 0.9646 - val_loss: 0.1397 - val_accuracy: 0.9670
# Epoch 36/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0290 - accuracy: 0.9927 - val_loss: 0.1200 - val_accuracy: 0.9560
# Epoch 37/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0714 - accuracy: 0.9780 - val_loss: 0.1427 - val_accuracy: 0.9670
# Epoch 38/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0670 - accuracy: 0.9768 - val_loss: 0.1650 - val_accuracy: 0.9451
# Epoch 39/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0516 - accuracy: 0.9805 - val_loss: 0.2678 - val_accuracy: 0.9451
# Epoch 40/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0369 - accuracy: 0.9927 - val_loss: 0.1658 - val_accuracy: 0.9560
# Epoch 41/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0905 - accuracy: 0.9744 - val_loss: 0.1701 - val_accuracy: 0.9560
# Epoch 42/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1340 - accuracy: 0.9585 - val_loss: 0.2093 - val_accuracy: 0.9670
# Epoch 43/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0783 - accuracy: 0.9768 - val_loss: 0.1892 - val_accuracy: 0.9670
# Epoch 44/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0798 - accuracy: 0.9780 - val_loss: 0.1669 - val_accuracy: 0.9670
# Epoch 45/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0825 - accuracy: 0.9731 - val_loss: 0.1522 - val_accuracy: 0.9560
# Epoch 46/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0936 - accuracy: 0.9670 - val_loss: 0.2030 - val_accuracy: 0.9231
# Epoch 47/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0566 - accuracy: 0.9792 - val_loss: 0.1353 - val_accuracy: 0.9560
# Epoch 48/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0628 - accuracy: 0.9768 - val_loss: 0.1931 - val_accuracy: 0.9560
# Epoch 49/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0380 - accuracy: 0.9829 - val_loss: 0.1343 - val_accuracy: 0.9560
# Epoch 50/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0550 - accuracy: 0.9817 - val_loss: 0.1856 - val_accuracy: 0.9560
# Epoch 51/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1063 - accuracy: 0.9695 - val_loss: 0.2115 - val_accuracy: 0.9231
# Epoch 52/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0798 - accuracy: 0.9792 - val_loss: 0.1110 - val_accuracy: 0.9560
# Epoch 53/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0970 - accuracy: 0.9707 - val_loss: 0.1807 - val_accuracy: 0.9451
# Epoch 54/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0564 - accuracy: 0.9805 - val_loss: 0.2233 - val_accuracy: 0.9341
# Epoch 55/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0703 - accuracy: 0.9805 - val_loss: 0.1507 - val_accuracy: 0.9341
# Epoch 56/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0811 - accuracy: 0.9756 - val_loss: 0.2236 - val_accuracy: 0.9451
# Epoch 57/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0353 - accuracy: 0.9866 - val_loss: 0.2613 - val_accuracy: 0.9231
# Epoch 58/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0674 - accuracy: 0.9805 - val_loss: 0.2265 - val_accuracy: 0.9341
# Epoch 59/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0378 - accuracy: 0.9853 - val_loss: 0.4285 - val_accuracy: 0.9451
# Epoch 60/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0265 - accuracy: 0.9915 - val_loss: 0.2342 - val_accuracy: 0.9451
# Epoch 61/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0997 - accuracy: 0.9683 - val_loss: 0.2700 - val_accuracy: 0.9341
# Epoch 62/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0959 - accuracy: 0.9707 - val_loss: 0.2740 - val_accuracy: 0.9451
# Epoch 63/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0719 - accuracy: 0.9829 - val_loss: 0.0963 - val_accuracy: 0.9780
# Epoch 64/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0542 - accuracy: 0.9829 - val_loss: 0.5351 - val_accuracy: 0.9121
# Epoch 65/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0911 - accuracy: 0.9719 - val_loss: 0.4334 - val_accuracy: 0.9231
# Epoch 66/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0854 - accuracy: 0.9731 - val_loss: 0.1367 - val_accuracy: 0.9780
# Epoch 67/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0480 - accuracy: 0.9829 - val_loss: 0.2892 - val_accuracy: 0.9451
# Epoch 68/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0318 - accuracy: 0.9927 - val_loss: 0.3561 - val_accuracy: 0.9341
# Epoch 69/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1409 - accuracy: 0.9719 - val_loss: 0.2949 - val_accuracy: 0.9341
# Epoch 70/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0788 - accuracy: 0.9683 - val_loss: 0.3409 - val_accuracy: 0.9560
# Epoch 71/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0466 - accuracy: 0.9817 - val_loss: 0.2239 - val_accuracy: 0.9560
# Epoch 72/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0775 - accuracy: 0.9731 - val_loss: 0.1388 - val_accuracy: 0.9560
# Epoch 73/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1047 - accuracy: 0.9670 - val_loss: 0.2006 - val_accuracy: 0.9560
# Epoch 74/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0282 - accuracy: 0.9927 - val_loss: 0.1940 - val_accuracy: 0.9560
# Epoch 75/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0310 - accuracy: 0.9939 - val_loss: 0.2244 - val_accuracy: 0.9670
# Epoch 76/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0401 - accuracy: 0.9866 - val_loss: 0.2716 - val_accuracy: 0.9560
# Epoch 77/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1025 - accuracy: 0.9768 - val_loss: 0.1707 - val_accuracy: 0.9670
# Epoch 78/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0540 - accuracy: 0.9878 - val_loss: 0.1772 - val_accuracy: 0.9560
# Epoch 79/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0763 - accuracy: 0.9719 - val_loss: 0.2037 - val_accuracy: 0.9451
# Epoch 80/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0588 - accuracy: 0.9853 - val_loss: 0.1057 - val_accuracy: 0.9670
# Epoch 81/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0833 - accuracy: 0.9817 - val_loss: 0.2277 - val_accuracy: 0.9560
# Epoch 82/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0481 - accuracy: 0.9878 - val_loss: 0.2529 - val_accuracy: 0.9560
# Epoch 83/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0725 - accuracy: 0.9829 - val_loss: 0.3028 - val_accuracy: 0.9341
# Epoch 84/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0532 - accuracy: 0.9866 - val_loss: 0.4273 - val_accuracy: 0.9231
# Epoch 85/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0445 - accuracy: 0.9829 - val_loss: 0.1507 - val_accuracy: 0.9670
# Epoch 86/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0418 - accuracy: 0.9878 - val_loss: 0.1987 - val_accuracy: 0.9560
# Epoch 87/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0471 - accuracy: 0.9817 - val_loss: 0.3197 - val_accuracy: 0.9341
# Epoch 88/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0423 - accuracy: 0.9853 - val_loss: 0.2181 - val_accuracy: 0.9670
# Epoch 89/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 0.9976 - val_loss: 0.1299 - val_accuracy: 0.9780
# Epoch 90/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0307 - accuracy: 0.9939 - val_loss: 0.1102 - val_accuracy: 0.9451
# Epoch 91/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0163 - accuracy: 0.9927 - val_loss: 0.1220 - val_accuracy: 0.9451
# Epoch 92/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0320 - accuracy: 0.9902 - val_loss: 0.3580 - val_accuracy: 0.9341
# Epoch 93/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0663 - accuracy: 0.9744 - val_loss: 0.1328 - val_accuracy: 0.9451
# Epoch 94/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0500 - accuracy: 0.9890 - val_loss: 0.3867 - val_accuracy: 0.9341
# Epoch 95/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0274 - accuracy: 0.9927 - val_loss: 0.2610 - val_accuracy: 0.9560
# Epoch 96/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0910 - accuracy: 0.9805 - val_loss: 0.2700 - val_accuracy: 0.9341
# Epoch 97/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0547 - accuracy: 0.9878 - val_loss: 0.3619 - val_accuracy: 0.9451
# Epoch 98/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0461 - accuracy: 0.9805 - val_loss: 0.0796 - val_accuracy: 0.9780
# Epoch 99/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1109 - accuracy: 0.9817 - val_loss: 0.2325 - val_accuracy: 0.9341
# Epoch 100/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0717 - accuracy: 0.9731 - val_loss: 0.3435 - val_accuracy: 0.9231

# %%
evaluate = model.evaluate(x_test, y_test, batch_size=16)

print("Loss={:.6f}, Accuracy={:.6f}".format(evaluate[0],evaluate[1]))
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5072 - accuracy: 0.9314
# Loss=0.507245, Accuracy=0.931373

# %%
# plot accuracy
plt.figure()
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.grid()
plt.legend(['Training', 'Validation'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('MLP Model')
plt.savefig('mlp_accuracy_sd.svg')

# %%
# make prediction for confusion_matrix
import os
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
predict = model.predict(x_test, batch_size=16)
emotions=['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful']

# predicted emotions from the test set
y_pred = np.argmax(predict, 1)
predicted_emo = []
for i in range(0,y_test.shape[0]):
    emo = emotions[y_pred[i]]
    predicted_emo.append(emo)

# get actual emotion
actual_emo = []
y_true = y_test
for i in range(0,y_test.shape[0]):
    emo = emotions[y_true[i]]
    actual_emo.append(emo)

# generate the confusion matrix
cm = confusion_matrix(actual_emo, predicted_emo)
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

index = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful']
columns = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful']
cm_df = pd.DataFrame(cm, index, columns)
plt.figure(figsize=(10, 6))
plt.title('Confusion Matrix of MLP')
sns.heatmap(cm_df, annot=True)
plt.savefig('mlp_cm_sd.svg')

# %%
# print unweighted average recall
print("UAR: ", cm.trace()/cm.shape[0])
# Out:
# UAR:  0.938888888888889
