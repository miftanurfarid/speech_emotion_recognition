# %% [markdown]
# Long Short-Term Memory - Speaker Independent

# %%
# import library
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random as rn

# %%
# clone dataset from github
# !git clone https://github.com/miftanurfarid/speech_emotion_recognition/
# Out:
# Cloning into 'speech_emotion_recognition'...
# remote: Enumerating objects: 6970, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 6970 (delta 66), reused 101 (delta 59), pack-reused 6861
# Receiving objects: 100% (6970/6970), 745.22 MiB | 25.38 MiB/s, done.
# Resolving deltas: 100% (386/386), done.
# Checking out files: 100% (5306/5306), done.

# %%
cd speech_emotion_recognition
# Out:
# /content/speech_emotion_recognition

# %%
np.random.seed(123)
rn.seed(123)
tf.random.set_seed(123)

# %%
# load feature data
data_path = 'data/song/' # choose song or speech
x_train = np.load(data_path + 'x_train.npy')
x_test  = np.load(data_path + 'x_test.npy')
y_train = np.load(data_path + 'y_train.npy')
y_test  = np.load(data_path + 'y_test.npy')

# reshape x untuk lstm
x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
x_test = x_test.reshape((x_test.shape[0], 1, x_test.shape[1]))

# if labels are not in integer, convert it, otherwise comment it
y_train = y_train.astype(int)
y_test = y_test.astype(int)

# %%
earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                             patience=10,
                                             restore_best_weights=True)
checkpointer = tf.keras.callbacks.ModelCheckpoint(
    filepath='/tmp/weights.hdf5', verbose=1, save_best_only=True)

# %%
# function to define model
def model_lstm():
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.BatchNormalization(axis=-1,
              input_shape=(x_train.shape[1], x_train.shape[2])))
    model.add(tf.keras.layers.LSTM(256, return_sequences=True))
    model.add(tf.keras.layers.LSTM(256, return_sequences=True))
    model.add(tf.keras.layers.LSTM(256, return_sequences=True))
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dropout(0.4))
    model.add(tf.keras.layers.Dense(6, activation='softmax'))

    # compile model: set loss, optimizer, metric
    model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                  optimizer=tf.keras.optimizers.Adam(),
                  metrics=['accuracy'])
    return model

# %%
# create the model
model = model_lstm()
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 1, 386)           1544
#  ormalization)
#
#  lstm (LSTM)                 (None, 1, 256)            658432
#
#  lstm_1 (LSTM)               (None, 1, 256)            525312
#
#  lstm_2 (LSTM)               (None, 1, 256)            525312
#
#  flatten (Flatten)           (None, 256)               0
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 6)                 1542
#
# =================================================================
# Total params: 1,712,142
# Trainable params: 1,711,370
# Non-trainable params: 772
# _________________________________________________________________
# None

# %%
# plot model
tf.keras.utils.plot_model(model,'lstm_model_si.pdf',show_shapes=True)

# %%
# train the model
hist = model.fit(x_train, 
                 y_train, 
                 epochs=100, 
                 shuffle=True, # mengacak data
                #  callbacks=earlystop, # akan berhenti saat konvergen meskipun belum sampai maksimal iterasi
                 validation_split=0.1, # 1% utk validasi
                 batch_size=16) # setiap 1 kali training ada 16 sampel
# Out:
# Epoch 1/100
# 47/47 [==============================] - 7s 51ms/step - loss: 1.5304 - accuracy: 0.3870 - val_loss: 1.5921 - val_accuracy: 0.2738
# Epoch 2/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.8033 - accuracy: 0.7061 - val_loss: 1.6182 - val_accuracy: 0.3929
# Epoch 3/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.4813 - accuracy: 0.8178 - val_loss: 1.1813 - val_accuracy: 0.5595
# Epoch 4/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.3247 - accuracy: 0.8870 - val_loss: 0.9904 - val_accuracy: 0.6667
# Epoch 5/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.2972 - accuracy: 0.8910 - val_loss: 1.2195 - val_accuracy: 0.6310
# Epoch 6/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.2180 - accuracy: 0.9176 - val_loss: 1.1884 - val_accuracy: 0.6786
# Epoch 7/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.2097 - accuracy: 0.9269 - val_loss: 1.2877 - val_accuracy: 0.6310
# Epoch 8/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.1683 - accuracy: 0.9508 - val_loss: 0.8507 - val_accuracy: 0.7500
# Epoch 9/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.1676 - accuracy: 0.9388 - val_loss: 1.7411 - val_accuracy: 0.6548
# Epoch 10/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.1840 - accuracy: 0.9375 - val_loss: 0.9122 - val_accuracy: 0.7262
# Epoch 11/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.1215 - accuracy: 0.9614 - val_loss: 1.3497 - val_accuracy: 0.7381
# Epoch 12/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0865 - accuracy: 0.9734 - val_loss: 0.9384 - val_accuracy: 0.7619
# Epoch 13/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.1719 - accuracy: 0.9468 - val_loss: 0.8732 - val_accuracy: 0.8095
# Epoch 14/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0979 - accuracy: 0.9668 - val_loss: 0.9865 - val_accuracy: 0.7738
# Epoch 15/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.1262 - accuracy: 0.9588 - val_loss: 0.9581 - val_accuracy: 0.7619
# Epoch 16/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.1346 - accuracy: 0.9535 - val_loss: 1.1227 - val_accuracy: 0.7857
# Epoch 17/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.1051 - accuracy: 0.9654 - val_loss: 1.2308 - val_accuracy: 0.7381
# Epoch 18/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0505 - accuracy: 0.9867 - val_loss: 0.8812 - val_accuracy: 0.7619
# Epoch 19/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0564 - accuracy: 0.9814 - val_loss: 1.1212 - val_accuracy: 0.7738
# Epoch 20/100
# 47/47 [==============================] - 1s 23ms/step - loss: 0.1112 - accuracy: 0.9601 - val_loss: 0.8827 - val_accuracy: 0.7857
# Epoch 21/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0995 - accuracy: 0.9641 - val_loss: 1.1914 - val_accuracy: 0.7619
# Epoch 22/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.1154 - accuracy: 0.9574 - val_loss: 1.1279 - val_accuracy: 0.7976
# Epoch 23/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0698 - accuracy: 0.9774 - val_loss: 1.0443 - val_accuracy: 0.7976
# Epoch 24/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0474 - accuracy: 0.9774 - val_loss: 0.9657 - val_accuracy: 0.8095
# Epoch 25/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0960 - accuracy: 0.9734 - val_loss: 1.0933 - val_accuracy: 0.8095
# Epoch 26/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0631 - accuracy: 0.9774 - val_loss: 1.3285 - val_accuracy: 0.7381
# Epoch 27/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0599 - accuracy: 0.9774 - val_loss: 1.0302 - val_accuracy: 0.7738
# Epoch 28/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0248 - accuracy: 0.9934 - val_loss: 1.1874 - val_accuracy: 0.7619
# Epoch 29/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0485 - accuracy: 0.9840 - val_loss: 1.5292 - val_accuracy: 0.7143
# Epoch 30/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0440 - accuracy: 0.9840 - val_loss: 1.3907 - val_accuracy: 0.7619
# Epoch 31/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0522 - accuracy: 0.9840 - val_loss: 1.2206 - val_accuracy: 0.7857
# Epoch 32/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0519 - accuracy: 0.9827 - val_loss: 1.1540 - val_accuracy: 0.7976
# Epoch 33/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0237 - accuracy: 0.9934 - val_loss: 1.1433 - val_accuracy: 0.7738
# Epoch 34/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0631 - accuracy: 0.9814 - val_loss: 1.6436 - val_accuracy: 0.7857
# Epoch 35/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0353 - accuracy: 0.9880 - val_loss: 1.5106 - val_accuracy: 0.7619
# Epoch 36/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0451 - accuracy: 0.9827 - val_loss: 1.3462 - val_accuracy: 0.7976
# Epoch 37/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0276 - accuracy: 0.9907 - val_loss: 1.4875 - val_accuracy: 0.7857
# Epoch 38/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0438 - accuracy: 0.9867 - val_loss: 1.5602 - val_accuracy: 0.7619
# Epoch 39/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.1186 - accuracy: 0.9654 - val_loss: 1.4916 - val_accuracy: 0.7500
# Epoch 40/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0346 - accuracy: 0.9894 - val_loss: 1.4606 - val_accuracy: 0.7500
# Epoch 41/100
# 47/47 [==============================] - 1s 23ms/step - loss: 0.0143 - accuracy: 0.9947 - val_loss: 1.4676 - val_accuracy: 0.7381
# Epoch 42/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0541 - accuracy: 0.9840 - val_loss: 1.7917 - val_accuracy: 0.7143
# Epoch 43/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0935 - accuracy: 0.9681 - val_loss: 1.4744 - val_accuracy: 0.7738
# Epoch 44/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0702 - accuracy: 0.9774 - val_loss: 1.0292 - val_accuracy: 0.8095
# Epoch 45/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0661 - accuracy: 0.9827 - val_loss: 1.3011 - val_accuracy: 0.7500
# Epoch 46/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0461 - accuracy: 0.9867 - val_loss: 1.1856 - val_accuracy: 0.7976
# Epoch 47/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0170 - accuracy: 0.9934 - val_loss: 1.2027 - val_accuracy: 0.7976
# Epoch 48/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0169 - accuracy: 0.9947 - val_loss: 1.2560 - val_accuracy: 0.7738
# Epoch 49/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0202 - accuracy: 0.9934 - val_loss: 1.2749 - val_accuracy: 0.7738
# Epoch 50/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0425 - accuracy: 0.9894 - val_loss: 1.2289 - val_accuracy: 0.7976
# Epoch 51/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0249 - accuracy: 0.9947 - val_loss: 1.2813 - val_accuracy: 0.7976
# Epoch 52/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0122 - accuracy: 0.9960 - val_loss: 1.5343 - val_accuracy: 0.7976
# Epoch 53/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0710 - accuracy: 0.9761 - val_loss: 1.3467 - val_accuracy: 0.7619
# Epoch 54/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0384 - accuracy: 0.9880 - val_loss: 0.9946 - val_accuracy: 0.8214
# Epoch 55/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0160 - accuracy: 0.9934 - val_loss: 1.1482 - val_accuracy: 0.8095
# Epoch 56/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 1.0752 - val_accuracy: 0.8333
# Epoch 57/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0092 - accuracy: 0.9987 - val_loss: 1.2404 - val_accuracy: 0.8095
# Epoch 58/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0760 - accuracy: 0.9774 - val_loss: 1.1934 - val_accuracy: 0.7976
# Epoch 59/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0291 - accuracy: 0.9920 - val_loss: 1.2413 - val_accuracy: 0.7857
# Epoch 60/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0315 - accuracy: 0.9907 - val_loss: 1.2955 - val_accuracy: 0.7976
# Epoch 61/100
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0411 - accuracy: 0.9880 - val_loss: 1.3559 - val_accuracy: 0.7976
# Epoch 62/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0191 - accuracy: 0.9907 - val_loss: 1.2843 - val_accuracy: 0.7976
# Epoch 63/100
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0213 - accuracy: 0.9947 - val_loss: 1.4239 - val_accuracy: 0.7976
# Epoch 64/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0210 - accuracy: 0.9947 - val_loss: 1.3828 - val_accuracy: 0.7619
# Epoch 65/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0335 - accuracy: 0.9920 - val_loss: 1.3338 - val_accuracy: 0.7738
# Epoch 66/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0116 - accuracy: 0.9973 - val_loss: 1.1981 - val_accuracy: 0.7976
# Epoch 67/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0394 - accuracy: 0.9907 - val_loss: 1.2809 - val_accuracy: 0.8095
# Epoch 68/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0162 - accuracy: 0.9973 - val_loss: 1.4799 - val_accuracy: 0.7738
# Epoch 69/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0167 - accuracy: 0.9960 - val_loss: 1.3037 - val_accuracy: 0.7738
# Epoch 70/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0279 - accuracy: 0.9934 - val_loss: 1.3764 - val_accuracy: 0.8095
# Epoch 71/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0412 - accuracy: 0.9894 - val_loss: 1.3480 - val_accuracy: 0.8095
# Epoch 72/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0105 - accuracy: 0.9960 - val_loss: 1.2027 - val_accuracy: 0.7857
# Epoch 73/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 1.3127 - val_accuracy: 0.7619
# Epoch 74/100
# 47/47 [==============================] - 1s 27ms/step - loss: 0.0096 - accuracy: 0.9973 - val_loss: 1.2577 - val_accuracy: 0.7619
# Epoch 75/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0114 - accuracy: 0.9947 - val_loss: 1.3365 - val_accuracy: 0.7976
# Epoch 76/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0384 - accuracy: 0.9880 - val_loss: 1.3280 - val_accuracy: 0.7738
# Epoch 77/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0284 - accuracy: 0.9934 - val_loss: 1.3823 - val_accuracy: 0.7857
# Epoch 78/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0134 - accuracy: 0.9987 - val_loss: 1.3729 - val_accuracy: 0.7738
# Epoch 79/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.4462 - val_accuracy: 0.7738
# Epoch 80/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0078 - accuracy: 0.9960 - val_loss: 1.3698 - val_accuracy: 0.7857
# Epoch 81/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0307 - accuracy: 0.9907 - val_loss: 1.5166 - val_accuracy: 0.7738
# Epoch 82/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0285 - accuracy: 0.9920 - val_loss: 1.4223 - val_accuracy: 0.7619
# Epoch 83/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0083 - accuracy: 0.9973 - val_loss: 1.4497 - val_accuracy: 0.7857
# Epoch 84/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0156 - accuracy: 0.9934 - val_loss: 1.5878 - val_accuracy: 0.7619
# Epoch 85/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0056 - accuracy: 0.9987 - val_loss: 1.4498 - val_accuracy: 0.7857
# Epoch 86/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0063 - accuracy: 0.9987 - val_loss: 1.5079 - val_accuracy: 0.7857
# Epoch 87/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0310 - accuracy: 0.9934 - val_loss: 1.5620 - val_accuracy: 0.7619
# Epoch 88/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0190 - accuracy: 0.9920 - val_loss: 1.3558 - val_accuracy: 0.7976
# Epoch 89/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0507 - accuracy: 0.9854 - val_loss: 1.4473 - val_accuracy: 0.7619
# Epoch 90/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0484 - accuracy: 0.9867 - val_loss: 1.5955 - val_accuracy: 0.7500
# Epoch 91/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0170 - accuracy: 0.9973 - val_loss: 1.3774 - val_accuracy: 0.8095
# Epoch 92/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0127 - accuracy: 0.9960 - val_loss: 1.5152 - val_accuracy: 0.7738
# Epoch 93/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0201 - accuracy: 0.9934 - val_loss: 1.3902 - val_accuracy: 0.8095
# Epoch 94/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0167 - accuracy: 0.9973 - val_loss: 1.1588 - val_accuracy: 0.8333
# Epoch 95/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0038 - accuracy: 0.9987 - val_loss: 1.3743 - val_accuracy: 0.8333
# Epoch 96/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0215 - accuracy: 0.9934 - val_loss: 1.4142 - val_accuracy: 0.8214
# Epoch 97/100
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0199 - accuracy: 0.9947 - val_loss: 1.4403 - val_accuracy: 0.7857
# Epoch 98/100
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0337 - accuracy: 0.9920 - val_loss: 1.1852 - val_accuracy: 0.8333
# Epoch 99/100
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0387 - accuracy: 0.9934 - val_loss: 1.1789 - val_accuracy: 0.8214
# Epoch 100/100
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0226 - accuracy: 0.9920 - val_loss: 1.3764 - val_accuracy: 0.7500

# %%
evaluate = model.evaluate(x_test, y_test, batch_size=16)

print("Loss={:.6f}, Accuracy={:.6f}".format(evaluate[0],evaluate[1]))
# Out:
# 11/11 [==============================] - 1s 8ms/step - loss: 1.0220 - accuracy: 0.7557
# Loss=1.021985, Accuracy=0.755682

# %%
# plot accuracy
plt.figure()
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.grid()
plt.legend(['Training', 'Validation'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('LSTM Model')
plt.savefig('lstm_accuracy_si.svg')

# %%
# make prediction for confusion_matrix
import os
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
predict = model.predict(x_test, batch_size=16)
emotions=['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful']

# predicted emotions from the test set
y_pred = np.argmax(predict, 1)
predicted_emo = []
for i in range(0,y_test.shape[0]):
    emo = emotions[y_pred[i]]
    predicted_emo.append(emo)

# get actual emotion
actual_emo = []
y_true = y_test
for i in range(0,y_test.shape[0]):
    emo = emotions[y_true[i]]
    actual_emo.append(emo)

# generate the confusion matrix
cm = confusion_matrix(actual_emo, predicted_emo)
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

index = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful']
columns = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful']
cm_df = pd.DataFrame(cm, index, columns)
plt.figure(figsize=(10, 6))
plt.title('Confusion Matrix of LSTM')
sns.heatmap(cm_df, annot=True)
plt.savefig('lstm_cm_si.svg')

# %%
# print unweighted average recall
print("UAR: ", cm.trace()/cm.shape[0])
# Out:
# UAR:  0.7708333333333334
