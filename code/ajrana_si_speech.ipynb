# %% [markdown]
# DNN Ajrana - Speaker Independent

# %%
# import library
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random as rn

# %%
# clone dataset from github
# !git clone https://github.com/miftanurfarid/speech_emotion_recognition/
# Out:
# Cloning into 'speech_emotion_recognition'...
# remote: Enumerating objects: 6987, done.
# remote: Counting objects: 100% (126/126), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 6987 (delta 77), reused 116 (delta 67), pack-reused 6861
# Receiving objects: 100% (6987/6987), 745.63 MiB | 13.95 MiB/s, done.
# Resolving deltas: 100% (397/397), done.
# Checking out files: 100% (5322/5322), done.

# %%
cd speech_emotion_recognition
# Out:
# /content/speech_emotion_recognition

# %%
np.random.seed(123)
rn.seed(123)
tf.random.set_seed(123)

# %%
# load feature data
data_path = 'data/speech/' # choose song or speech
x_train = np.load(data_path + 'x_train_ajrana.npy')
x_test  = np.load(data_path + 'x_test_ajrana.npy')
y_train = np.load(data_path + 'y_train_ajrana.npy')
y_test  = np.load(data_path + 'y_test_ajrana.npy')

# %%
earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                             patience=10,
                                             restore_best_weights=True)

checkpointer = tf.keras.callbacks.ModelCheckpoint(
    filepath='/tmp/weights.hdf5', verbose=1, save_best_only=True)

# %%
# function to build model
def model_dense():
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.BatchNormalization(axis=-1,
              input_shape=(x_train.shape[1:])))
    model.add(tf.keras.layers.Dense(100, activation='relu'))
    model.add(tf.keras.layers.Dropout(0.2))
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(8, activation='softmax'))

    # compile model: set loss, optimizer, metric
    model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                  optimizer=tf.keras.optimizers.Adam(),
                  metrics=['accuracy'])
    return model

# %%
# create the model
model = model_dense()
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 40)               160
#  ormalization)
#
#  dense (Dense)               (None, 100)               4100
#
#  dropout (Dropout)           (None, 100)               0
#
#  flatten (Flatten)           (None, 100)               0
#
#  dense_1 (Dense)             (None, 8)                 808
#
# =================================================================
# Total params: 5,068
# Trainable params: 4,988
# Non-trainable params: 80
# _________________________________________________________________
# None

# %%
# plot model
tf.keras.utils.plot_model(model,'ajrana_model_si_speech.pdf',show_shapes=True)

# %%
# train the model
hist = model.fit(x_train, 
                 y_train, 
                 epochs=100, 
                 shuffle=True,
                 #callbacks=earlystop,
                 validation_split=0.1,
                 batch_size=16)
# Out:
# Epoch 1/100
# 68/68 [==============================] - 1s 6ms/step - loss: 2.0673 - accuracy: 0.1889 - val_loss: 2.1848 - val_accuracy: 0.2333
# Epoch 2/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.8384 - accuracy: 0.2750 - val_loss: 1.9574 - val_accuracy: 0.2583
# Epoch 3/100
# 68/68 [==============================] - 0s 4ms/step - loss: 1.7031 - accuracy: 0.3287 - val_loss: 1.8364 - val_accuracy: 0.3333
# Epoch 4/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.6109 - accuracy: 0.3907 - val_loss: 1.7869 - val_accuracy: 0.3333
# Epoch 5/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.5601 - accuracy: 0.4250 - val_loss: 1.7583 - val_accuracy: 0.3333
# Epoch 6/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.4996 - accuracy: 0.4380 - val_loss: 1.7208 - val_accuracy: 0.3750
# Epoch 7/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.4145 - accuracy: 0.4741 - val_loss: 1.7053 - val_accuracy: 0.3500
# Epoch 8/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.4023 - accuracy: 0.4926 - val_loss: 1.6842 - val_accuracy: 0.3583
# Epoch 9/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.3483 - accuracy: 0.5185 - val_loss: 1.6704 - val_accuracy: 0.3667
# Epoch 10/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.2966 - accuracy: 0.5324 - val_loss: 1.6747 - val_accuracy: 0.3917
# Epoch 11/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.2792 - accuracy: 0.5370 - val_loss: 1.6390 - val_accuracy: 0.3833
# Epoch 12/100
# 68/68 [==============================] - 0s 2ms/step - loss: 1.2395 - accuracy: 0.5509 - val_loss: 1.6598 - val_accuracy: 0.4083
# Epoch 13/100
# 68/68 [==============================] - 0s 2ms/step - loss: 1.2079 - accuracy: 0.5611 - val_loss: 1.6022 - val_accuracy: 0.4167
# Epoch 14/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.2051 - accuracy: 0.5537 - val_loss: 1.6390 - val_accuracy: 0.4167
# Epoch 15/100
# 68/68 [==============================] - 0s 4ms/step - loss: 1.1766 - accuracy: 0.5620 - val_loss: 1.6433 - val_accuracy: 0.4083
# Epoch 16/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.1743 - accuracy: 0.5824 - val_loss: 1.6636 - val_accuracy: 0.4250
# Epoch 17/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.0825 - accuracy: 0.6222 - val_loss: 1.6326 - val_accuracy: 0.4250
# Epoch 18/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.0963 - accuracy: 0.6231 - val_loss: 1.6828 - val_accuracy: 0.4083
# Epoch 19/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.0835 - accuracy: 0.6000 - val_loss: 1.6337 - val_accuracy: 0.4833
# Epoch 20/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.0529 - accuracy: 0.6222 - val_loss: 1.6469 - val_accuracy: 0.4500
# Epoch 21/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.0411 - accuracy: 0.6306 - val_loss: 1.6416 - val_accuracy: 0.4500
# Epoch 22/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.0439 - accuracy: 0.6102 - val_loss: 1.6693 - val_accuracy: 0.4167
# Epoch 23/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.0219 - accuracy: 0.6500 - val_loss: 1.6786 - val_accuracy: 0.4083
# Epoch 24/100
# 68/68 [==============================] - 0s 3ms/step - loss: 1.0160 - accuracy: 0.6333 - val_loss: 1.6510 - val_accuracy: 0.4500
# Epoch 25/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.9911 - accuracy: 0.6426 - val_loss: 1.6674 - val_accuracy: 0.4500
# Epoch 26/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.9905 - accuracy: 0.6204 - val_loss: 1.6281 - val_accuracy: 0.4833
# Epoch 27/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.9548 - accuracy: 0.6611 - val_loss: 1.6579 - val_accuracy: 0.4667
# Epoch 28/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.9440 - accuracy: 0.6685 - val_loss: 1.6603 - val_accuracy: 0.4500
# Epoch 29/100
# 68/68 [==============================] - 0s 4ms/step - loss: 0.9612 - accuracy: 0.6602 - val_loss: 1.6863 - val_accuracy: 0.4667
# Epoch 30/100
# 68/68 [==============================] - 0s 4ms/step - loss: 0.9172 - accuracy: 0.6694 - val_loss: 1.6672 - val_accuracy: 0.4583
# Epoch 31/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.9390 - accuracy: 0.6435 - val_loss: 1.6941 - val_accuracy: 0.4667
# Epoch 32/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.9107 - accuracy: 0.6852 - val_loss: 1.6941 - val_accuracy: 0.4250
# Epoch 33/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.9222 - accuracy: 0.6537 - val_loss: 1.6590 - val_accuracy: 0.4333
# Epoch 34/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8958 - accuracy: 0.6648 - val_loss: 1.7279 - val_accuracy: 0.4583
# Epoch 35/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8996 - accuracy: 0.6843 - val_loss: 1.7156 - val_accuracy: 0.4417
# Epoch 36/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8934 - accuracy: 0.6759 - val_loss: 1.7178 - val_accuracy: 0.4417
# Epoch 37/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8518 - accuracy: 0.6852 - val_loss: 1.7262 - val_accuracy: 0.4333
# Epoch 38/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8530 - accuracy: 0.7037 - val_loss: 1.7135 - val_accuracy: 0.4250
# Epoch 39/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8633 - accuracy: 0.6815 - val_loss: 1.7273 - val_accuracy: 0.4583
# Epoch 40/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8462 - accuracy: 0.6991 - val_loss: 1.6835 - val_accuracy: 0.4750
# Epoch 41/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8437 - accuracy: 0.7037 - val_loss: 1.6690 - val_accuracy: 0.4667
# Epoch 42/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8362 - accuracy: 0.6944 - val_loss: 1.7079 - val_accuracy: 0.4667
# Epoch 43/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8639 - accuracy: 0.6963 - val_loss: 1.6863 - val_accuracy: 0.4750
# Epoch 44/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7666 - accuracy: 0.7407 - val_loss: 1.7179 - val_accuracy: 0.4500
# Epoch 45/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7956 - accuracy: 0.7259 - val_loss: 1.7764 - val_accuracy: 0.4500
# Epoch 46/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7815 - accuracy: 0.7296 - val_loss: 1.7842 - val_accuracy: 0.4500
# Epoch 47/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8069 - accuracy: 0.7093 - val_loss: 1.7880 - val_accuracy: 0.5083
# Epoch 48/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8243 - accuracy: 0.7111 - val_loss: 1.7637 - val_accuracy: 0.4750
# Epoch 49/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7710 - accuracy: 0.7167 - val_loss: 1.7378 - val_accuracy: 0.4667
# Epoch 50/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8138 - accuracy: 0.6981 - val_loss: 1.7431 - val_accuracy: 0.5167
# Epoch 51/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.7919 - accuracy: 0.7167 - val_loss: 1.7168 - val_accuracy: 0.5000
# Epoch 52/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7838 - accuracy: 0.7361 - val_loss: 1.7306 - val_accuracy: 0.5083
# Epoch 53/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7653 - accuracy: 0.7361 - val_loss: 1.7445 - val_accuracy: 0.4917
# Epoch 54/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7703 - accuracy: 0.7241 - val_loss: 1.7294 - val_accuracy: 0.5083
# Epoch 55/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7206 - accuracy: 0.7481 - val_loss: 1.7162 - val_accuracy: 0.5250
# Epoch 56/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7280 - accuracy: 0.7463 - val_loss: 1.7392 - val_accuracy: 0.5083
# Epoch 57/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7472 - accuracy: 0.7148 - val_loss: 1.6970 - val_accuracy: 0.4917
# Epoch 58/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7173 - accuracy: 0.7389 - val_loss: 1.7601 - val_accuracy: 0.4667
# Epoch 59/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7171 - accuracy: 0.7407 - val_loss: 1.7555 - val_accuracy: 0.5000
# Epoch 60/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7244 - accuracy: 0.7380 - val_loss: 1.8392 - val_accuracy: 0.4833
# Epoch 61/100
# 68/68 [==============================] - 0s 4ms/step - loss: 0.7482 - accuracy: 0.7222 - val_loss: 1.7875 - val_accuracy: 0.5000
# Epoch 62/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7099 - accuracy: 0.7509 - val_loss: 1.7801 - val_accuracy: 0.4917
# Epoch 63/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7505 - accuracy: 0.7259 - val_loss: 1.7831 - val_accuracy: 0.5167
# Epoch 64/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7177 - accuracy: 0.7472 - val_loss: 1.7207 - val_accuracy: 0.5083
# Epoch 65/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6978 - accuracy: 0.7630 - val_loss: 1.7711 - val_accuracy: 0.4917
# Epoch 66/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.6389 - accuracy: 0.7843 - val_loss: 1.7904 - val_accuracy: 0.5083
# Epoch 67/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6879 - accuracy: 0.7528 - val_loss: 1.8290 - val_accuracy: 0.5000
# Epoch 68/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.6793 - accuracy: 0.7611 - val_loss: 1.8196 - val_accuracy: 0.5333
# Epoch 69/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.7046 - accuracy: 0.7454 - val_loss: 1.7844 - val_accuracy: 0.5250
# Epoch 70/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6824 - accuracy: 0.7500 - val_loss: 1.8360 - val_accuracy: 0.5417
# Epoch 71/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6900 - accuracy: 0.7630 - val_loss: 1.8532 - val_accuracy: 0.5000
# Epoch 72/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7144 - accuracy: 0.7407 - val_loss: 1.8523 - val_accuracy: 0.5000
# Epoch 73/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6454 - accuracy: 0.7907 - val_loss: 1.8920 - val_accuracy: 0.5083
# Epoch 74/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7235 - accuracy: 0.7250 - val_loss: 1.7894 - val_accuracy: 0.5167
# Epoch 75/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6681 - accuracy: 0.7519 - val_loss: 1.7963 - val_accuracy: 0.5083
# Epoch 76/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6429 - accuracy: 0.7778 - val_loss: 1.8614 - val_accuracy: 0.5083
# Epoch 77/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6723 - accuracy: 0.7565 - val_loss: 1.9089 - val_accuracy: 0.4917
# Epoch 78/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6304 - accuracy: 0.7759 - val_loss: 1.8913 - val_accuracy: 0.4833
# Epoch 79/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6578 - accuracy: 0.7694 - val_loss: 1.9015 - val_accuracy: 0.4917
# Epoch 80/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6450 - accuracy: 0.7759 - val_loss: 1.9434 - val_accuracy: 0.4833
# Epoch 81/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6036 - accuracy: 0.7972 - val_loss: 1.8799 - val_accuracy: 0.4833
# Epoch 82/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6325 - accuracy: 0.7685 - val_loss: 1.8841 - val_accuracy: 0.5000
# Epoch 83/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5987 - accuracy: 0.8037 - val_loss: 1.9305 - val_accuracy: 0.4667
# Epoch 84/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6208 - accuracy: 0.7806 - val_loss: 1.9331 - val_accuracy: 0.4917
# Epoch 85/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.5970 - accuracy: 0.7750 - val_loss: 1.9658 - val_accuracy: 0.5000
# Epoch 86/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6258 - accuracy: 0.7630 - val_loss: 1.9149 - val_accuracy: 0.5250
# Epoch 87/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.6223 - accuracy: 0.7713 - val_loss: 1.9746 - val_accuracy: 0.5000
# Epoch 88/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.6028 - accuracy: 0.7843 - val_loss: 1.9963 - val_accuracy: 0.4833
# Epoch 89/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6180 - accuracy: 0.7898 - val_loss: 1.9735 - val_accuracy: 0.5333
# Epoch 90/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6173 - accuracy: 0.7769 - val_loss: 1.9546 - val_accuracy: 0.4917
# Epoch 91/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6082 - accuracy: 0.7815 - val_loss: 1.9005 - val_accuracy: 0.5333
# Epoch 92/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6225 - accuracy: 0.7833 - val_loss: 2.0403 - val_accuracy: 0.5000
# Epoch 93/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.6218 - accuracy: 0.7963 - val_loss: 1.9934 - val_accuracy: 0.5167
# Epoch 94/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.5372 - accuracy: 0.8009 - val_loss: 2.0142 - val_accuracy: 0.5250
# Epoch 95/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.5786 - accuracy: 0.7806 - val_loss: 2.0306 - val_accuracy: 0.5083
# Epoch 96/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.5719 - accuracy: 0.7907 - val_loss: 1.9708 - val_accuracy: 0.5000
# Epoch 97/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.5887 - accuracy: 0.7981 - val_loss: 1.9914 - val_accuracy: 0.5167
# Epoch 98/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.5876 - accuracy: 0.7880 - val_loss: 1.9812 - val_accuracy: 0.5083
# Epoch 99/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6068 - accuracy: 0.7796 - val_loss: 1.9453 - val_accuracy: 0.5500
# Epoch 100/100
# 68/68 [==============================] - 0s 3ms/step - loss: 0.5253 - accuracy: 0.8269 - val_loss: 1.9749 - val_accuracy: 0.5167

# %%
evaluate = model.evaluate(x_test, y_test, batch_size=16)

print("Loss={:.6f}, Accuracy={:.6f}".format(evaluate[0],evaluate[1]))
# Out:
# 15/15 [==============================] - 0s 3ms/step - loss: 1.9091 - accuracy: 0.3500
# Loss=1.909091, Accuracy=0.350000

# %%
# plot accuracy
plt.figure()
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.grid()
plt.legend(['Training', 'Validation'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Ajrana Model')
plt.savefig('ajrana_accuracy_si_speech.svg')

# %%
# make prediction for confusion_matrix
import os
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
predict = model.predict(x_test, batch_size=16)
emotions = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprise']

# predicted emotions from the test set
y_pred = np.argmax(predict, 1)
predicted_emo = []
for i in range(0,y_test.shape[0]):
    emo = emotions[y_pred[i]]
    predicted_emo.append(emo)

# get actual emotion
actual_emo = []
y_true = y_test
for i in range(0,y_test.shape[0]):
    emo = emotions[y_true[i]]
    actual_emo.append(emo)

# generate the confusion matrix
cm = confusion_matrix(actual_emo, predicted_emo)
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

index = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprise']
columns = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprise']
cm_df = pd.DataFrame(cm, index, columns)
plt.figure(figsize=(10, 6))
plt.title('Confusion Matrix of Ajrana')
sns.heatmap(cm_df, annot=True)
plt.savefig('ajrana_cm_si_speech.svg')

# %%
# print unweighted average recall
print("UAR: ", cm.trace()/cm.shape[0])
# Out:
# UAR:  0.3359375
