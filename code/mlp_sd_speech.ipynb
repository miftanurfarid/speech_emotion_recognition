# %% [markdown]
# Multi Layer Perceptron - Speaker Dependent

# %%
# import library
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random as rn

# %%
# clone dataset from github
# !git clone https://github.com/miftanurfarid/speech_emotion_recognition/
# Out:
# Cloning into 'speech_emotion_recognition'...
# remote: Enumerating objects: 6987, done.
# remote: Counting objects: 100% (126/126), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 6987 (delta 77), reused 116 (delta 67), pack-reused 6861
# Receiving objects: 100% (6987/6987), 745.63 MiB | 22.00 MiB/s, done.
# Resolving deltas: 100% (397/397), done.
# Checking out files: 100% (5322/5322), done.

# %%
cd speech_emotion_recognition
# Out:
# /content/speech_emotion_recognition

# %%
np.random.seed(123)
rn.seed(123)
tf.random.set_seed(123)

# %%
# load feature data
data_path = 'data/speech/' # choose song or speech
X = np.load(data_path + 'x.npy')
y = np.load(data_path + 'y.npy')

# %%
# split into train and test
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                             patience=10,
                                             restore_best_weights=True)

checkpointer = tf.keras.callbacks.ModelCheckpoint(
    filepath='/tmp/weights.hdf5', verbose=1, save_best_only=True)

# %%
# function to build model
def model_dense():
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.BatchNormalization(axis=-1,
              input_shape=(x_train.shape[1:])))
    model.add(tf.keras.layers.Dense(256, activation='relu'))
    model.add(tf.keras.layers.Dense(256, activation='relu'))
    model.add(tf.keras.layers.Dense(256, activation='relu'))
    model.add(tf.keras.layers.Dropout(0.4))
    model.add(tf.keras.layers.Dense(8, activation='softmax'))

    # compile model: set loss, optimizer, metric
    model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                  optimizer=tf.keras.optimizers.Adam(),
                  metrics=['accuracy'])
    return model

# %%
# create the model
model = model_dense()
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 386)              1544
#  ormalization)
#
#  dense (Dense)               (None, 256)               99072
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_3 (Dense)             (None, 8)                 2056
#
# =================================================================
# Total params: 234,256
# Trainable params: 233,484
# Non-trainable params: 772
# _________________________________________________________________
# None

# %%
# plot model
tf.keras.utils.plot_model(model,'mlp_model_sd_speech.pdf',show_shapes=True)

# %%
# train the model
hist = model.fit(x_train, 
                 y_train, 
                 epochs=100, 
                 shuffle=True,
                 #callbacks=earlystop,
                 validation_split=0.1,
                 batch_size=16)
# Out:
# Epoch 1/100
# 73/73 [==============================] - 2s 11ms/step - loss: 1.8156 - accuracy: 0.3182 - val_loss: 2.1399 - val_accuracy: 0.2462
# Epoch 2/100
# 73/73 [==============================] - 1s 7ms/step - loss: 1.4567 - accuracy: 0.4666 - val_loss: 1.9768 - val_accuracy: 0.3615
# Epoch 3/100
# 73/73 [==============================] - 1s 7ms/step - loss: 1.2464 - accuracy: 0.5386 - val_loss: 1.3970 - val_accuracy: 0.4846
# Epoch 4/100
# 73/73 [==============================] - 1s 8ms/step - loss: 1.0857 - accuracy: 0.6012 - val_loss: 1.1987 - val_accuracy: 0.6154
# Epoch 5/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.9111 - accuracy: 0.6655 - val_loss: 1.1194 - val_accuracy: 0.6385
# Epoch 6/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.8379 - accuracy: 0.6973 - val_loss: 1.0951 - val_accuracy: 0.6538
# Epoch 7/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.7607 - accuracy: 0.7324 - val_loss: 1.0774 - val_accuracy: 0.6154
# Epoch 8/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.6084 - accuracy: 0.7873 - val_loss: 0.8455 - val_accuracy: 0.7000
# Epoch 9/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.5991 - accuracy: 0.7899 - val_loss: 0.8833 - val_accuracy: 0.6769
# Epoch 10/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.5325 - accuracy: 0.8156 - val_loss: 0.7531 - val_accuracy: 0.7462
# Epoch 11/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.4803 - accuracy: 0.8448 - val_loss: 0.7631 - val_accuracy: 0.7923
# Epoch 12/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.4692 - accuracy: 0.8388 - val_loss: 0.7963 - val_accuracy: 0.7308
# Epoch 13/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.4591 - accuracy: 0.8405 - val_loss: 1.1035 - val_accuracy: 0.6538
# Epoch 14/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.3800 - accuracy: 0.8662 - val_loss: 0.7840 - val_accuracy: 0.7846
# Epoch 15/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.3617 - accuracy: 0.8774 - val_loss: 0.8373 - val_accuracy: 0.6923
# Epoch 16/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.3398 - accuracy: 0.8756 - val_loss: 0.6424 - val_accuracy: 0.7923
# Epoch 17/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.3239 - accuracy: 0.8894 - val_loss: 0.7697 - val_accuracy: 0.7769
# Epoch 18/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.3024 - accuracy: 0.8971 - val_loss: 0.6757 - val_accuracy: 0.7462
# Epoch 19/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.3229 - accuracy: 0.8859 - val_loss: 0.7101 - val_accuracy: 0.7462
# Epoch 20/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.2235 - accuracy: 0.9254 - val_loss: 0.6789 - val_accuracy: 0.7615
# Epoch 21/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.2204 - accuracy: 0.9202 - val_loss: 0.6393 - val_accuracy: 0.7923
# Epoch 22/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.2284 - accuracy: 0.9228 - val_loss: 0.7699 - val_accuracy: 0.7538
# Epoch 23/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.2333 - accuracy: 0.9288 - val_loss: 0.8464 - val_accuracy: 0.7462
# Epoch 24/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.2318 - accuracy: 0.9262 - val_loss: 0.8887 - val_accuracy: 0.7385
# Epoch 25/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.2249 - accuracy: 0.9305 - val_loss: 0.6686 - val_accuracy: 0.7385
# Epoch 26/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.1867 - accuracy: 0.9408 - val_loss: 0.7014 - val_accuracy: 0.7462
# Epoch 27/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.1629 - accuracy: 0.9468 - val_loss: 0.6645 - val_accuracy: 0.7692
# Epoch 28/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.1482 - accuracy: 0.9468 - val_loss: 0.8325 - val_accuracy: 0.7308
# Epoch 29/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.1734 - accuracy: 0.9391 - val_loss: 0.5807 - val_accuracy: 0.8000
# Epoch 30/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.1437 - accuracy: 0.9443 - val_loss: 0.7564 - val_accuracy: 0.7692
# Epoch 31/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.1330 - accuracy: 0.9571 - val_loss: 0.5711 - val_accuracy: 0.7923
# Epoch 32/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.1407 - accuracy: 0.9511 - val_loss: 0.6146 - val_accuracy: 0.7769
# Epoch 33/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.1087 - accuracy: 0.9563 - val_loss: 0.6855 - val_accuracy: 0.7846
# Epoch 34/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.2085 - accuracy: 0.9400 - val_loss: 0.7161 - val_accuracy: 0.7462
# Epoch 35/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.1488 - accuracy: 0.9563 - val_loss: 0.7015 - val_accuracy: 0.8000
# Epoch 36/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.1143 - accuracy: 0.9657 - val_loss: 0.8693 - val_accuracy: 0.7692
# Epoch 37/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.1375 - accuracy: 0.9597 - val_loss: 0.4880 - val_accuracy: 0.8231
# Epoch 38/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0771 - accuracy: 0.9743 - val_loss: 0.6621 - val_accuracy: 0.7846
# Epoch 39/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.1262 - accuracy: 0.9597 - val_loss: 1.0141 - val_accuracy: 0.7308
# Epoch 40/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.1374 - accuracy: 0.9520 - val_loss: 1.0959 - val_accuracy: 0.7769
# Epoch 41/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.1805 - accuracy: 0.9425 - val_loss: 0.7174 - val_accuracy: 0.7692
# Epoch 42/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.1175 - accuracy: 0.9571 - val_loss: 0.7206 - val_accuracy: 0.7692
# Epoch 43/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0917 - accuracy: 0.9691 - val_loss: 0.7822 - val_accuracy: 0.7462
# Epoch 44/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.1148 - accuracy: 0.9571 - val_loss: 0.9077 - val_accuracy: 0.7615
# Epoch 45/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0791 - accuracy: 0.9743 - val_loss: 0.6925 - val_accuracy: 0.7923
# Epoch 46/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.1094 - accuracy: 0.9683 - val_loss: 0.9799 - val_accuracy: 0.7231
# Epoch 47/100
# 73/73 [==============================] - 0s 5ms/step - loss: 0.1384 - accuracy: 0.9520 - val_loss: 0.8681 - val_accuracy: 0.7846
# Epoch 48/100
# 73/73 [==============================] - 0s 5ms/step - loss: 0.1364 - accuracy: 0.9571 - val_loss: 0.7865 - val_accuracy: 0.7692
# Epoch 49/100
# 73/73 [==============================] - 0s 6ms/step - loss: 0.1657 - accuracy: 0.9571 - val_loss: 0.7686 - val_accuracy: 0.7538
# Epoch 50/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0789 - accuracy: 0.9811 - val_loss: 0.7212 - val_accuracy: 0.7846
# Epoch 51/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0376 - accuracy: 0.9880 - val_loss: 0.8327 - val_accuracy: 0.7846
# Epoch 52/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0810 - accuracy: 0.9760 - val_loss: 0.8844 - val_accuracy: 0.7692
# Epoch 53/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0810 - accuracy: 0.9760 - val_loss: 0.6920 - val_accuracy: 0.7615
# Epoch 54/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.1079 - accuracy: 0.9674 - val_loss: 0.9299 - val_accuracy: 0.7385
# Epoch 55/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0930 - accuracy: 0.9640 - val_loss: 0.7417 - val_accuracy: 0.7923
# Epoch 56/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0637 - accuracy: 0.9786 - val_loss: 0.8602 - val_accuracy: 0.7385
# Epoch 57/100
# 73/73 [==============================] - 0s 5ms/step - loss: 0.0947 - accuracy: 0.9751 - val_loss: 0.7565 - val_accuracy: 0.8000
# Epoch 58/100
# 73/73 [==============================] - 0s 5ms/step - loss: 0.0453 - accuracy: 0.9863 - val_loss: 0.7248 - val_accuracy: 0.7923
# Epoch 59/100
# 73/73 [==============================] - 0s 5ms/step - loss: 0.0825 - accuracy: 0.9743 - val_loss: 0.8986 - val_accuracy: 0.7692
# Epoch 60/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0649 - accuracy: 0.9777 - val_loss: 0.9027 - val_accuracy: 0.7846
# Epoch 61/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0855 - accuracy: 0.9743 - val_loss: 0.9605 - val_accuracy: 0.7923
# Epoch 62/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0880 - accuracy: 0.9760 - val_loss: 0.7821 - val_accuracy: 0.7923
# Epoch 63/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0869 - accuracy: 0.9726 - val_loss: 0.8780 - val_accuracy: 0.7308
# Epoch 64/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0981 - accuracy: 0.9640 - val_loss: 0.7408 - val_accuracy: 0.7538
# Epoch 65/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.1172 - accuracy: 0.9648 - val_loss: 0.8711 - val_accuracy: 0.7769
# Epoch 66/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.1208 - accuracy: 0.9674 - val_loss: 0.7505 - val_accuracy: 0.7769
# Epoch 67/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0970 - accuracy: 0.9743 - val_loss: 0.7377 - val_accuracy: 0.7923
# Epoch 68/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0721 - accuracy: 0.9777 - val_loss: 0.8550 - val_accuracy: 0.7538
# Epoch 69/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0744 - accuracy: 0.9768 - val_loss: 0.6554 - val_accuracy: 0.8077
# Epoch 70/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0939 - accuracy: 0.9691 - val_loss: 0.8107 - val_accuracy: 0.7923
# Epoch 71/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0465 - accuracy: 0.9846 - val_loss: 0.6645 - val_accuracy: 0.8308
# Epoch 72/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0468 - accuracy: 0.9863 - val_loss: 0.6923 - val_accuracy: 0.8000
# Epoch 73/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0469 - accuracy: 0.9828 - val_loss: 0.7708 - val_accuracy: 0.7692
# Epoch 74/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0682 - accuracy: 0.9786 - val_loss: 0.7109 - val_accuracy: 0.7923
# Epoch 75/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0796 - accuracy: 0.9768 - val_loss: 0.5623 - val_accuracy: 0.8231
# Epoch 76/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0567 - accuracy: 0.9837 - val_loss: 0.6557 - val_accuracy: 0.8077
# Epoch 77/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.1146 - accuracy: 0.9734 - val_loss: 0.7284 - val_accuracy: 0.7923
# Epoch 78/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0998 - accuracy: 0.9683 - val_loss: 0.7959 - val_accuracy: 0.7615
# Epoch 79/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0954 - accuracy: 0.9683 - val_loss: 0.7468 - val_accuracy: 0.7923
# Epoch 80/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0513 - accuracy: 0.9820 - val_loss: 0.8752 - val_accuracy: 0.7846
# Epoch 81/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0782 - accuracy: 0.9837 - val_loss: 0.8303 - val_accuracy: 0.8000
# Epoch 82/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0841 - accuracy: 0.9743 - val_loss: 0.9156 - val_accuracy: 0.7538
# Epoch 83/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0494 - accuracy: 0.9811 - val_loss: 0.8361 - val_accuracy: 0.7846
# Epoch 84/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0916 - accuracy: 0.9726 - val_loss: 0.8388 - val_accuracy: 0.7692
# Epoch 85/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0569 - accuracy: 0.9794 - val_loss: 1.0003 - val_accuracy: 0.8000
# Epoch 86/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0864 - accuracy: 0.9674 - val_loss: 0.8747 - val_accuracy: 0.7846
# Epoch 87/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.1067 - accuracy: 0.9700 - val_loss: 0.8701 - val_accuracy: 0.7769
# Epoch 88/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0802 - accuracy: 0.9786 - val_loss: 0.8518 - val_accuracy: 0.8077
# Epoch 89/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0777 - accuracy: 0.9786 - val_loss: 1.1886 - val_accuracy: 0.7923
# Epoch 90/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0893 - accuracy: 0.9708 - val_loss: 0.9924 - val_accuracy: 0.7538
# Epoch 91/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0604 - accuracy: 0.9820 - val_loss: 0.7232 - val_accuracy: 0.8077
# Epoch 92/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0274 - accuracy: 0.9906 - val_loss: 0.7317 - val_accuracy: 0.7923
# Epoch 93/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0289 - accuracy: 0.9889 - val_loss: 0.8186 - val_accuracy: 0.8000
# Epoch 94/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0335 - accuracy: 0.9889 - val_loss: 0.7290 - val_accuracy: 0.8154
# Epoch 95/100
# 73/73 [==============================] - 1s 7ms/step - loss: 0.0647 - accuracy: 0.9820 - val_loss: 0.9157 - val_accuracy: 0.8000
# Epoch 96/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0340 - accuracy: 0.9897 - val_loss: 0.8773 - val_accuracy: 0.8000
# Epoch 97/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0934 - accuracy: 0.9743 - val_loss: 1.0212 - val_accuracy: 0.7462
# Epoch 98/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0946 - accuracy: 0.9691 - val_loss: 1.0264 - val_accuracy: 0.7769
# Epoch 99/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0637 - accuracy: 0.9828 - val_loss: 0.8332 - val_accuracy: 0.7692
# Epoch 100/100
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0655 - accuracy: 0.9828 - val_loss: 1.0994 - val_accuracy: 0.7769

# %%
evaluate = model.evaluate(x_test, y_test, batch_size=16)

print("Loss={:.6f}, Accuracy={:.6f}".format(evaluate[0],evaluate[1]))
# Out:
# 9/9 [==============================] - 0s 4ms/step - loss: 1.5098 - accuracy: 0.7222
# Loss=1.509781, Accuracy=0.722222

# %%
# plot accuracy
plt.figure()
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.grid()
plt.legend(['Training', 'Validation'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('MLP Model')
plt.savefig('mlp_accuracy_sd_speech.svg')

# %%
# make prediction for confusion_matrix
import os
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
predict = model.predict(x_test, batch_size=16)
emotions = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprise']

# predicted emotions from the test set
y_pred = np.argmax(predict, 1)
predicted_emo = []
for i in range(0,y_test.shape[0]):
    emo = emotions[y_pred[i]]
    predicted_emo.append(emo)

# get actual emotion
actual_emo = []
y_true = y_test
for i in range(0,y_test.shape[0]):
    emo = emotions[y_true[i]]
    actual_emo.append(emo)

# generate the confusion matrix
cm = confusion_matrix(actual_emo, predicted_emo)
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

index = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprise']
columns = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprise']
cm_df = pd.DataFrame(cm, index, columns)
plt.figure(figsize=(10, 6))
plt.title('Confusion Matrix of MLP')
sns.heatmap(cm_df, annot=True)
plt.savefig('mlp_cm_sd_speech.svg')

# %%
# print unweighted average recall
print("UAR: ", cm.trace()/cm.shape[0])
# Out:
# UAR:  0.7284591769885888
