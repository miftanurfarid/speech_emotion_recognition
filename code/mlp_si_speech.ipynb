# %% [markdown]
# Multi Layer Perceptron - Speaker Independent

# %%
# import library
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random as rn

# %%
# clone dataset from github
# !git clone https://github.com/miftanurfarid/speech_emotion_recognition/
# Out:
# Cloning into 'speech_emotion_recognition'...
# remote: Enumerating objects: 6987, done.
# remote: Counting objects: 100% (126/126), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 6987 (delta 77), reused 116 (delta 67), pack-reused 6861
# Receiving objects: 100% (6987/6987), 745.63 MiB | 24.79 MiB/s, done.
# Resolving deltas: 100% (397/397), done.
# Checking out files: 100% (5322/5322), done.

# %%
cd speech_emotion_recognition
# Out:
# /content/speech_emotion_recognition

# %%
np.random.seed(123)
rn.seed(123)
tf.random.set_seed(123)

# %%
# load feature data
data_path = 'data/speech/' # choose song or speech
x_train = np.load(data_path + 'x_train.npy')
x_test  = np.load(data_path + 'x_test.npy')
y_train = np.load(data_path + 'y_train.npy')
y_test  = np.load(data_path + 'y_test.npy')

# %%
earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                             patience=10,
                                             restore_best_weights=True)

checkpointer = tf.keras.callbacks.ModelCheckpoint(
    filepath='/tmp/weights.hdf5', verbose=1, save_best_only=True)

# %%
# function to build model
def model_dense():
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.BatchNormalization(axis=-1,
              input_shape=(x_train.shape[1:])))
    model.add(tf.keras.layers.Dense(256, activation='relu'))
    model.add(tf.keras.layers.Dense(256, activation='relu'))
    model.add(tf.keras.layers.Dense(256, activation='relu'))
    model.add(tf.keras.layers.Dropout(0.4))
    model.add(tf.keras.layers.Dense(8, activation='softmax'))

    # compile model: set loss, optimizer, metric
    model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                  optimizer=tf.keras.optimizers.Adam(),
                  metrics=['accuracy'])
    return model

# %%
# create the model
model = model_dense()
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 386)              1544
#  ormalization)
#
#  dense (Dense)               (None, 256)               99072
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_3 (Dense)             (None, 8)                 2056
#
# =================================================================
# Total params: 234,256
# Trainable params: 233,484
# Non-trainable params: 772
# _________________________________________________________________
# None

# %%
# plot model
tf.keras.utils.plot_model(model,'mlp_model_si_speech.pdf',show_shapes=True)

# %%
# train the model
hist = model.fit(x_train, 
                 y_train, 
                 epochs=100, 
                 shuffle=True,
                 #callbacks=earlystop,
                 validation_split=0.1,
                 batch_size=16)
# Out:
# Epoch 1/100
# 68/68 [==============================] - 2s 10ms/step - loss: 1.8625 - accuracy: 0.3046 - val_loss: 2.2987 - val_accuracy: 0.1917
# Epoch 2/100
# 68/68 [==============================] - 1s 7ms/step - loss: 1.4198 - accuracy: 0.4704 - val_loss: 2.0887 - val_accuracy: 0.3333
# Epoch 3/100
# 68/68 [==============================] - 0s 7ms/step - loss: 1.1891 - accuracy: 0.5583 - val_loss: 1.6533 - val_accuracy: 0.4333
# Epoch 4/100
# 68/68 [==============================] - 0s 6ms/step - loss: 1.0479 - accuracy: 0.6213 - val_loss: 1.3835 - val_accuracy: 0.4917
# Epoch 5/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.9106 - accuracy: 0.6741 - val_loss: 1.5871 - val_accuracy: 0.4833
# Epoch 6/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.8065 - accuracy: 0.6981 - val_loss: 1.4702 - val_accuracy: 0.4667
# Epoch 7/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.6371 - accuracy: 0.7833 - val_loss: 1.5264 - val_accuracy: 0.4917
# Epoch 8/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.6245 - accuracy: 0.7769 - val_loss: 1.6193 - val_accuracy: 0.4833
# Epoch 9/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.5987 - accuracy: 0.7907 - val_loss: 1.7158 - val_accuracy: 0.4583
# Epoch 10/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.4993 - accuracy: 0.8093 - val_loss: 1.6706 - val_accuracy: 0.5500
# Epoch 11/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.4325 - accuracy: 0.8481 - val_loss: 1.9357 - val_accuracy: 0.5083
# Epoch 12/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.5032 - accuracy: 0.8278 - val_loss: 1.5815 - val_accuracy: 0.5000
# Epoch 13/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.3474 - accuracy: 0.8796 - val_loss: 1.4523 - val_accuracy: 0.5250
# Epoch 14/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.3436 - accuracy: 0.8806 - val_loss: 1.9415 - val_accuracy: 0.5167
# Epoch 15/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.3547 - accuracy: 0.8787 - val_loss: 2.0850 - val_accuracy: 0.4750
# Epoch 16/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.3285 - accuracy: 0.8787 - val_loss: 1.6418 - val_accuracy: 0.5667
# Epoch 17/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.2516 - accuracy: 0.9120 - val_loss: 1.9770 - val_accuracy: 0.5000
# Epoch 18/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.2554 - accuracy: 0.9185 - val_loss: 1.9398 - val_accuracy: 0.5000
# Epoch 19/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.2382 - accuracy: 0.9278 - val_loss: 2.0849 - val_accuracy: 0.5250
# Epoch 20/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.2034 - accuracy: 0.9324 - val_loss: 2.1627 - val_accuracy: 0.4750
# Epoch 21/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.1817 - accuracy: 0.9296 - val_loss: 2.5059 - val_accuracy: 0.4500
# Epoch 22/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.1980 - accuracy: 0.9278 - val_loss: 2.6317 - val_accuracy: 0.4333
# Epoch 23/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.2628 - accuracy: 0.9148 - val_loss: 2.1428 - val_accuracy: 0.5167
# Epoch 24/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1895 - accuracy: 0.9361 - val_loss: 1.9866 - val_accuracy: 0.4917
# Epoch 25/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.2007 - accuracy: 0.9324 - val_loss: 2.3918 - val_accuracy: 0.4333
# Epoch 26/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.2379 - accuracy: 0.9231 - val_loss: 2.1833 - val_accuracy: 0.5083
# Epoch 27/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1290 - accuracy: 0.9528 - val_loss: 2.0724 - val_accuracy: 0.5333
# Epoch 28/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1186 - accuracy: 0.9611 - val_loss: 2.1547 - val_accuracy: 0.5333
# Epoch 29/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1442 - accuracy: 0.9509 - val_loss: 2.7744 - val_accuracy: 0.5167
# Epoch 30/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1393 - accuracy: 0.9537 - val_loss: 2.2375 - val_accuracy: 0.5250
# Epoch 31/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1346 - accuracy: 0.9648 - val_loss: 2.2849 - val_accuracy: 0.5083
# Epoch 32/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1163 - accuracy: 0.9685 - val_loss: 2.4619 - val_accuracy: 0.5417
# Epoch 33/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1297 - accuracy: 0.9574 - val_loss: 2.3290 - val_accuracy: 0.5250
# Epoch 34/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1225 - accuracy: 0.9620 - val_loss: 2.4126 - val_accuracy: 0.5417
# Epoch 35/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1754 - accuracy: 0.9435 - val_loss: 2.5730 - val_accuracy: 0.5000
# Epoch 36/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1547 - accuracy: 0.9509 - val_loss: 2.1735 - val_accuracy: 0.5250
# Epoch 37/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1398 - accuracy: 0.9583 - val_loss: 2.3110 - val_accuracy: 0.5000
# Epoch 38/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1155 - accuracy: 0.9685 - val_loss: 2.1452 - val_accuracy: 0.5333
# Epoch 39/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1438 - accuracy: 0.9519 - val_loss: 2.1895 - val_accuracy: 0.5250
# Epoch 40/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0667 - accuracy: 0.9778 - val_loss: 2.4695 - val_accuracy: 0.5333
# Epoch 41/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0892 - accuracy: 0.9741 - val_loss: 2.2254 - val_accuracy: 0.5667
# Epoch 42/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.1107 - accuracy: 0.9648 - val_loss: 2.1567 - val_accuracy: 0.5500
# Epoch 43/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1268 - accuracy: 0.9648 - val_loss: 2.0848 - val_accuracy: 0.5833
# Epoch 44/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1253 - accuracy: 0.9611 - val_loss: 2.5859 - val_accuracy: 0.5417
# Epoch 45/100
# 68/68 [==============================] - 1s 8ms/step - loss: 0.1137 - accuracy: 0.9676 - val_loss: 2.2281 - val_accuracy: 0.5000
# Epoch 46/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.1048 - accuracy: 0.9667 - val_loss: 1.9386 - val_accuracy: 0.5583
# Epoch 47/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1709 - accuracy: 0.9417 - val_loss: 2.4047 - val_accuracy: 0.5417
# Epoch 48/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0894 - accuracy: 0.9704 - val_loss: 1.9968 - val_accuracy: 0.5750
# Epoch 49/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0874 - accuracy: 0.9685 - val_loss: 2.2139 - val_accuracy: 0.5167
# Epoch 50/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0992 - accuracy: 0.9685 - val_loss: 2.5934 - val_accuracy: 0.4583
# Epoch 51/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1253 - accuracy: 0.9574 - val_loss: 2.9252 - val_accuracy: 0.4583
# Epoch 52/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0926 - accuracy: 0.9685 - val_loss: 2.3654 - val_accuracy: 0.5333
# Epoch 53/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0800 - accuracy: 0.9731 - val_loss: 2.0725 - val_accuracy: 0.5333
# Epoch 54/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0661 - accuracy: 0.9787 - val_loss: 2.5329 - val_accuracy: 0.5083
# Epoch 55/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0512 - accuracy: 0.9824 - val_loss: 1.9126 - val_accuracy: 0.5583
# Epoch 56/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0618 - accuracy: 0.9778 - val_loss: 2.5952 - val_accuracy: 0.4917
# Epoch 57/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0469 - accuracy: 0.9824 - val_loss: 2.6825 - val_accuracy: 0.5167
# Epoch 58/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0559 - accuracy: 0.9787 - val_loss: 3.1662 - val_accuracy: 0.4750
# Epoch 59/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0799 - accuracy: 0.9694 - val_loss: 2.6295 - val_accuracy: 0.5750
# Epoch 60/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1096 - accuracy: 0.9676 - val_loss: 2.8284 - val_accuracy: 0.5250
# Epoch 61/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1569 - accuracy: 0.9435 - val_loss: 2.3012 - val_accuracy: 0.5500
# Epoch 62/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0754 - accuracy: 0.9741 - val_loss: 2.8288 - val_accuracy: 0.4750
# Epoch 63/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1495 - accuracy: 0.9593 - val_loss: 2.8111 - val_accuracy: 0.4667
# Epoch 64/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0668 - accuracy: 0.9769 - val_loss: 2.6303 - val_accuracy: 0.5083
# Epoch 65/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.1144 - accuracy: 0.9639 - val_loss: 2.2832 - val_accuracy: 0.5500
# Epoch 66/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0428 - accuracy: 0.9852 - val_loss: 2.5155 - val_accuracy: 0.5083
# Epoch 67/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0526 - accuracy: 0.9824 - val_loss: 2.3450 - val_accuracy: 0.5250
# Epoch 68/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0562 - accuracy: 0.9880 - val_loss: 2.5845 - val_accuracy: 0.5167
# Epoch 69/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0786 - accuracy: 0.9778 - val_loss: 2.1570 - val_accuracy: 0.5417
# Epoch 70/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0885 - accuracy: 0.9704 - val_loss: 2.3418 - val_accuracy: 0.5583
# Epoch 71/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1107 - accuracy: 0.9694 - val_loss: 2.3204 - val_accuracy: 0.5583
# Epoch 72/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0648 - accuracy: 0.9796 - val_loss: 2.3674 - val_accuracy: 0.5500
# Epoch 73/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0701 - accuracy: 0.9787 - val_loss: 2.6949 - val_accuracy: 0.5167
# Epoch 74/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0592 - accuracy: 0.9824 - val_loss: 3.1181 - val_accuracy: 0.5083
# Epoch 75/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0822 - accuracy: 0.9731 - val_loss: 2.1009 - val_accuracy: 0.5667
# Epoch 76/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0708 - accuracy: 0.9787 - val_loss: 2.6629 - val_accuracy: 0.5083
# Epoch 77/100
# 68/68 [==============================] - 1s 8ms/step - loss: 0.0766 - accuracy: 0.9769 - val_loss: 2.8840 - val_accuracy: 0.5000
# Epoch 78/100
# 68/68 [==============================] - 1s 8ms/step - loss: 0.0467 - accuracy: 0.9806 - val_loss: 2.5527 - val_accuracy: 0.5333
# Epoch 79/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0311 - accuracy: 0.9944 - val_loss: 2.8446 - val_accuracy: 0.4917
# Epoch 80/100
# 68/68 [==============================] - 1s 7ms/step - loss: 0.0477 - accuracy: 0.9796 - val_loss: 3.1342 - val_accuracy: 0.4750
# Epoch 81/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0815 - accuracy: 0.9806 - val_loss: 2.7290 - val_accuracy: 0.5333
# Epoch 82/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1195 - accuracy: 0.9620 - val_loss: 2.5203 - val_accuracy: 0.5500
# Epoch 83/100
# 68/68 [==============================] - 1s 8ms/step - loss: 0.1307 - accuracy: 0.9676 - val_loss: 2.5363 - val_accuracy: 0.5667
# Epoch 84/100
# 68/68 [==============================] - 1s 8ms/step - loss: 0.0670 - accuracy: 0.9815 - val_loss: 2.5682 - val_accuracy: 0.5500
# Epoch 85/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0761 - accuracy: 0.9750 - val_loss: 3.0532 - val_accuracy: 0.5333
# Epoch 86/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0377 - accuracy: 0.9898 - val_loss: 3.0508 - val_accuracy: 0.4917
# Epoch 87/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.1077 - accuracy: 0.9731 - val_loss: 2.6236 - val_accuracy: 0.5250
# Epoch 88/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0805 - accuracy: 0.9750 - val_loss: 4.0665 - val_accuracy: 0.4583
# Epoch 89/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0700 - accuracy: 0.9750 - val_loss: 3.4815 - val_accuracy: 0.4917
# Epoch 90/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0280 - accuracy: 0.9917 - val_loss: 3.4642 - val_accuracy: 0.4750
# Epoch 91/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0930 - accuracy: 0.9704 - val_loss: 2.9881 - val_accuracy: 0.4917
# Epoch 92/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0615 - accuracy: 0.9852 - val_loss: 2.6555 - val_accuracy: 0.5500
# Epoch 93/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0346 - accuracy: 0.9907 - val_loss: 2.9344 - val_accuracy: 0.5167
# Epoch 94/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0364 - accuracy: 0.9898 - val_loss: 2.8285 - val_accuracy: 0.5083
# Epoch 95/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0292 - accuracy: 0.9917 - val_loss: 3.1265 - val_accuracy: 0.5083
# Epoch 96/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0398 - accuracy: 0.9861 - val_loss: 3.1246 - val_accuracy: 0.4833
# Epoch 97/100
# 68/68 [==============================] - 0s 7ms/step - loss: 0.0242 - accuracy: 0.9907 - val_loss: 2.8746 - val_accuracy: 0.5083
# Epoch 98/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0303 - accuracy: 0.9907 - val_loss: 2.7149 - val_accuracy: 0.5083
# Epoch 99/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0916 - accuracy: 0.9787 - val_loss: 3.2501 - val_accuracy: 0.4583
# Epoch 100/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0831 - accuracy: 0.9769 - val_loss: 3.2742 - val_accuracy: 0.4500

# %%
evaluate = model.evaluate(x_test, y_test, batch_size=16)

print("Loss={:.6f}, Accuracy={:.6f}".format(evaluate[0],evaluate[1]))
# Out:
# 15/15 [==============================] - 0s 2ms/step - loss: 4.6438 - accuracy: 0.4208
# Loss=4.643767, Accuracy=0.420833

# %%
# plot accuracy
plt.figure()
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.grid()
plt.legend(['Training', 'Validation'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('MLP Model')
plt.savefig('mlp_accuracy_si_speech.svg')

# %%
# make prediction for confusion_matrix
import os
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
predict = model.predict(x_test, batch_size=16)
emotions = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprise']

# predicted emotions from the test set
y_pred = np.argmax(predict, 1)
predicted_emo = []
for i in range(0,y_test.shape[0]):
    emo = emotions[y_pred[i]]
    predicted_emo.append(emo)

# get actual emotion
actual_emo = []
y_true = y_test
for i in range(0,y_test.shape[0]):
    emo = emotions[y_true[i]]
    actual_emo.append(emo)

# generate the confusion matrix
cm = confusion_matrix(actual_emo, predicted_emo)
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

index = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprise']
columns = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprise']
cm_df = pd.DataFrame(cm, index, columns)
plt.figure(figsize=(10, 6))
plt.title('Confusion Matrix of MLP')
sns.heatmap(cm_df, annot=True)
plt.savefig('mlp_cm_si_speech.svg')

# %%
# print unweighted average recall
print("UAR: ", cm.trace()/cm.shape[0])
# Out:
# UAR:  0.40625
