# %% [markdown]
# DNN Ajrana - Speaker Dependent

# %%
# import library
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random as rn

# %%
# clone dataset from github
# !git clone https://github.com/miftanurfarid/speech_emotion_recognition/
# Out:
# Cloning into 'speech_emotion_recognition'...
# remote: Enumerating objects: 6987, done.
# remote: Counting objects: 100% (126/126), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 6987 (delta 77), reused 116 (delta 67), pack-reused 6861
# Receiving objects: 100% (6987/6987), 745.63 MiB | 25.35 MiB/s, done.
# Resolving deltas: 100% (397/397), done.
# Checking out files: 100% (5322/5322), done.

# %%
cd speech_emotion_recognition
# Out:
# /content/speech_emotion_recognition

# %%
np.random.seed(123)
rn.seed(123)
tf.random.set_seed(123)

# %%
# load feature data
data_path = 'data/speech/' # choose song or speech
X = np.load(data_path + 'x_ajrana.npy')
y = np.load(data_path + 'y_ajrana.npy')

# %%
# split into train and test
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                             patience=10,
                                             restore_best_weights=True)

checkpointer = tf.keras.callbacks.ModelCheckpoint(
    filepath='/tmp/weights.hdf5', verbose=1, save_best_only=True)

# %%
# function to build model
def model_dense():
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.BatchNormalization(axis=-1,
              input_shape=(x_train.shape[1:])))
    model.add(tf.keras.layers.Dense(100, activation='relu'))
    model.add(tf.keras.layers.Dropout(0.2))
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(8, activation='softmax'))

    # compile model: set loss, optimizer, metric
    model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                  optimizer=tf.keras.optimizers.Adam(),
                  metrics=['accuracy'])
    return model

# %%
# create the model
model = model_dense()
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 40)               160
#  ormalization)
#
#  dense (Dense)               (None, 100)               4100
#
#  dropout (Dropout)           (None, 100)               0
#
#  flatten (Flatten)           (None, 100)               0
#
#  dense_1 (Dense)             (None, 8)                 808
#
# =================================================================
# Total params: 5,068
# Trainable params: 4,988
# Non-trainable params: 80
# _________________________________________________________________
# None

# %%
# plot model
tf.keras.utils.plot_model(model,'ajrana_model_sd_speech.pdf',show_shapes=True)

# %%
# train the model
hist = model.fit(x_train, 
                 y_train, 
                 epochs=100, 
                 shuffle=True,
                 #callbacks=earlystop,
                 validation_split=0.1,
                 batch_size=16)
# Out:
# Epoch 1/100
# 73/73 [==============================] - 1s 5ms/step - loss: 2.0817 - accuracy: 0.1955 - val_loss: 1.9260 - val_accuracy: 0.2231
# Epoch 2/100
# 73/73 [==============================] - 0s 2ms/step - loss: 1.8408 - accuracy: 0.2770 - val_loss: 1.7596 - val_accuracy: 0.3077
# Epoch 3/100
# 73/73 [==============================] - 0s 2ms/step - loss: 1.7378 - accuracy: 0.3233 - val_loss: 1.6474 - val_accuracy: 0.3846
# Epoch 4/100
# 73/73 [==============================] - 0s 2ms/step - loss: 1.6462 - accuracy: 0.3954 - val_loss: 1.5603 - val_accuracy: 0.4538
# Epoch 5/100
# 73/73 [==============================] - 0s 3ms/step - loss: 1.5649 - accuracy: 0.4125 - val_loss: 1.5443 - val_accuracy: 0.4308
# Epoch 6/100
# 73/73 [==============================] - 0s 3ms/step - loss: 1.5200 - accuracy: 0.4262 - val_loss: 1.4523 - val_accuracy: 0.5308
# Epoch 7/100
# 73/73 [==============================] - 0s 3ms/step - loss: 1.4878 - accuracy: 0.4503 - val_loss: 1.4282 - val_accuracy: 0.4923
# Epoch 8/100
# 73/73 [==============================] - 0s 3ms/step - loss: 1.4057 - accuracy: 0.4828 - val_loss: 1.3701 - val_accuracy: 0.5000
# Epoch 9/100
# 73/73 [==============================] - 0s 2ms/step - loss: 1.3978 - accuracy: 0.4966 - val_loss: 1.3330 - val_accuracy: 0.5308
# Epoch 10/100
# 73/73 [==============================] - 0s 2ms/step - loss: 1.3399 - accuracy: 0.5094 - val_loss: 1.3048 - val_accuracy: 0.5769
# Epoch 11/100
# 73/73 [==============================] - 0s 2ms/step - loss: 1.3016 - accuracy: 0.5154 - val_loss: 1.2961 - val_accuracy: 0.5615
# Epoch 12/100
# 73/73 [==============================] - 0s 3ms/step - loss: 1.3004 - accuracy: 0.5086 - val_loss: 1.2596 - val_accuracy: 0.5615
# Epoch 13/100
# 73/73 [==============================] - 0s 3ms/step - loss: 1.2565 - accuracy: 0.5557 - val_loss: 1.2428 - val_accuracy: 0.5846
# Epoch 14/100
# 73/73 [==============================] - 0s 2ms/step - loss: 1.2538 - accuracy: 0.5334 - val_loss: 1.2204 - val_accuracy: 0.5692
# Epoch 15/100
# 73/73 [==============================] - 0s 3ms/step - loss: 1.2167 - accuracy: 0.5557 - val_loss: 1.1798 - val_accuracy: 0.5692
# Epoch 16/100
# 73/73 [==============================] - 0s 3ms/step - loss: 1.1897 - accuracy: 0.5772 - val_loss: 1.1644 - val_accuracy: 0.6077
# Epoch 17/100
# 73/73 [==============================] - 0s 2ms/step - loss: 1.1679 - accuracy: 0.5815 - val_loss: 1.1482 - val_accuracy: 0.6308
# Epoch 18/100
# 73/73 [==============================] - 0s 3ms/step - loss: 1.1711 - accuracy: 0.5858 - val_loss: 1.1177 - val_accuracy: 0.6385
# Epoch 19/100
# 73/73 [==============================] - 0s 2ms/step - loss: 1.1683 - accuracy: 0.5738 - val_loss: 1.1272 - val_accuracy: 0.6154
# Epoch 20/100
# 73/73 [==============================] - 0s 2ms/step - loss: 1.1425 - accuracy: 0.5943 - val_loss: 1.1159 - val_accuracy: 0.6385
# Epoch 21/100
# 73/73 [==============================] - 0s 2ms/step - loss: 1.1364 - accuracy: 0.6021 - val_loss: 1.1094 - val_accuracy: 0.6231
# Epoch 22/100
# 73/73 [==============================] - 0s 2ms/step - loss: 1.0925 - accuracy: 0.6201 - val_loss: 1.0518 - val_accuracy: 0.6308
# Epoch 23/100
# 73/73 [==============================] - 0s 3ms/step - loss: 1.0865 - accuracy: 0.6106 - val_loss: 1.0977 - val_accuracy: 0.6385
# Epoch 24/100
# 73/73 [==============================] - 0s 2ms/step - loss: 1.1022 - accuracy: 0.6166 - val_loss: 1.0552 - val_accuracy: 0.6769
# Epoch 25/100
# 73/73 [==============================] - 0s 2ms/step - loss: 1.0580 - accuracy: 0.6304 - val_loss: 1.0436 - val_accuracy: 0.6692
# Epoch 26/100
# 73/73 [==============================] - 0s 2ms/step - loss: 1.0439 - accuracy: 0.6158 - val_loss: 1.0250 - val_accuracy: 0.6692
# Epoch 27/100
# 73/73 [==============================] - 0s 3ms/step - loss: 1.0636 - accuracy: 0.6038 - val_loss: 1.0117 - val_accuracy: 0.6769
# Epoch 28/100
# 73/73 [==============================] - 0s 2ms/step - loss: 1.0276 - accuracy: 0.6055 - val_loss: 1.0099 - val_accuracy: 0.6769
# Epoch 29/100
# 73/73 [==============================] - 0s 2ms/step - loss: 1.0252 - accuracy: 0.6415 - val_loss: 0.9956 - val_accuracy: 0.6846
# Epoch 30/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.9607 - accuracy: 0.6604 - val_loss: 1.0092 - val_accuracy: 0.6923
# Epoch 31/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.9710 - accuracy: 0.6424 - val_loss: 1.0196 - val_accuracy: 0.6846
# Epoch 32/100
# 73/73 [==============================] - 0s 3ms/step - loss: 1.0031 - accuracy: 0.6424 - val_loss: 0.9828 - val_accuracy: 0.6923
# Epoch 33/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.9361 - accuracy: 0.6509 - val_loss: 0.9774 - val_accuracy: 0.6846
# Epoch 34/100
# 73/73 [==============================] - 0s 2ms/step - loss: 1.0219 - accuracy: 0.6278 - val_loss: 0.9892 - val_accuracy: 0.6692
# Epoch 35/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.9476 - accuracy: 0.6621 - val_loss: 0.9897 - val_accuracy: 0.6769
# Epoch 36/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.9625 - accuracy: 0.6552 - val_loss: 1.0033 - val_accuracy: 0.6846
# Epoch 37/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.9006 - accuracy: 0.6913 - val_loss: 0.9636 - val_accuracy: 0.6769
# Epoch 38/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.8993 - accuracy: 0.6775 - val_loss: 0.9887 - val_accuracy: 0.6692
# Epoch 39/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.9235 - accuracy: 0.6681 - val_loss: 0.9638 - val_accuracy: 0.7077
# Epoch 40/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.9530 - accuracy: 0.6518 - val_loss: 0.9471 - val_accuracy: 0.6846
# Epoch 41/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.9448 - accuracy: 0.6690 - val_loss: 0.9482 - val_accuracy: 0.6692
# Epoch 42/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.9140 - accuracy: 0.6784 - val_loss: 0.9373 - val_accuracy: 0.6769
# Epoch 43/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.9236 - accuracy: 0.6604 - val_loss: 0.9218 - val_accuracy: 0.7077
# Epoch 44/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.8801 - accuracy: 0.6715 - val_loss: 0.9338 - val_accuracy: 0.7000
# Epoch 45/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.8595 - accuracy: 0.6938 - val_loss: 0.9244 - val_accuracy: 0.7154
# Epoch 46/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.8802 - accuracy: 0.6844 - val_loss: 0.9232 - val_accuracy: 0.6923
# Epoch 47/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.8859 - accuracy: 0.6758 - val_loss: 0.9182 - val_accuracy: 0.6846
# Epoch 48/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.8814 - accuracy: 0.6827 - val_loss: 0.9033 - val_accuracy: 0.7077
# Epoch 49/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.8682 - accuracy: 0.6861 - val_loss: 0.9356 - val_accuracy: 0.6923
# Epoch 50/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.8381 - accuracy: 0.7161 - val_loss: 0.8950 - val_accuracy: 0.7154
# Epoch 51/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.8360 - accuracy: 0.6973 - val_loss: 0.9185 - val_accuracy: 0.7000
# Epoch 52/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.8660 - accuracy: 0.6998 - val_loss: 0.8926 - val_accuracy: 0.7231
# Epoch 53/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.8711 - accuracy: 0.6861 - val_loss: 0.9111 - val_accuracy: 0.7231
# Epoch 54/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.8423 - accuracy: 0.7050 - val_loss: 0.9169 - val_accuracy: 0.7000
# Epoch 55/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.8130 - accuracy: 0.7290 - val_loss: 0.9339 - val_accuracy: 0.6923
# Epoch 56/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.8014 - accuracy: 0.7101 - val_loss: 0.8919 - val_accuracy: 0.7231
# Epoch 57/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.8062 - accuracy: 0.7204 - val_loss: 0.8815 - val_accuracy: 0.7231
# Epoch 58/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7976 - accuracy: 0.7281 - val_loss: 0.9060 - val_accuracy: 0.7000
# Epoch 59/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.8055 - accuracy: 0.7041 - val_loss: 0.9076 - val_accuracy: 0.7615
# Epoch 60/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.7940 - accuracy: 0.7144 - val_loss: 0.8932 - val_accuracy: 0.7077
# Epoch 61/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7709 - accuracy: 0.7376 - val_loss: 0.8750 - val_accuracy: 0.7462
# Epoch 62/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.8092 - accuracy: 0.7050 - val_loss: 0.8799 - val_accuracy: 0.7308
# Epoch 63/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7925 - accuracy: 0.7136 - val_loss: 0.8891 - val_accuracy: 0.7231
# Epoch 64/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7687 - accuracy: 0.7290 - val_loss: 0.8669 - val_accuracy: 0.7462
# Epoch 65/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.7753 - accuracy: 0.7196 - val_loss: 0.8781 - val_accuracy: 0.7154
# Epoch 66/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7640 - accuracy: 0.7170 - val_loss: 0.8860 - val_accuracy: 0.7077
# Epoch 67/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7486 - accuracy: 0.7367 - val_loss: 0.8702 - val_accuracy: 0.7077
# Epoch 68/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7296 - accuracy: 0.7410 - val_loss: 0.8502 - val_accuracy: 0.7308
# Epoch 69/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7367 - accuracy: 0.7521 - val_loss: 0.8700 - val_accuracy: 0.7154
# Epoch 70/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7079 - accuracy: 0.7444 - val_loss: 0.8577 - val_accuracy: 0.7231
# Epoch 71/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7196 - accuracy: 0.7461 - val_loss: 0.8550 - val_accuracy: 0.7077
# Epoch 72/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7190 - accuracy: 0.7419 - val_loss: 0.8636 - val_accuracy: 0.7077
# Epoch 73/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7499 - accuracy: 0.7419 - val_loss: 0.8515 - val_accuracy: 0.7308
# Epoch 74/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7676 - accuracy: 0.7264 - val_loss: 0.8227 - val_accuracy: 0.7154
# Epoch 75/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.6801 - accuracy: 0.7676 - val_loss: 0.8305 - val_accuracy: 0.7154
# Epoch 76/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7226 - accuracy: 0.7341 - val_loss: 0.8304 - val_accuracy: 0.7231
# Epoch 77/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7111 - accuracy: 0.7316 - val_loss: 0.8469 - val_accuracy: 0.7231
# Epoch 78/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.7288 - accuracy: 0.7298 - val_loss: 0.8371 - val_accuracy: 0.7385
# Epoch 79/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7476 - accuracy: 0.7367 - val_loss: 0.8318 - val_accuracy: 0.7615
# Epoch 80/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7048 - accuracy: 0.7547 - val_loss: 0.8177 - val_accuracy: 0.7692
# Epoch 81/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.6948 - accuracy: 0.7444 - val_loss: 0.8349 - val_accuracy: 0.7615
# Epoch 82/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7201 - accuracy: 0.7444 - val_loss: 0.8246 - val_accuracy: 0.7385
# Epoch 83/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.6841 - accuracy: 0.7710 - val_loss: 0.8107 - val_accuracy: 0.7462
# Epoch 84/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7170 - accuracy: 0.7521 - val_loss: 0.8092 - val_accuracy: 0.7385
# Epoch 85/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.6886 - accuracy: 0.7590 - val_loss: 0.8205 - val_accuracy: 0.7692
# Epoch 86/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.6704 - accuracy: 0.7633 - val_loss: 0.8390 - val_accuracy: 0.7538
# Epoch 87/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.6971 - accuracy: 0.7521 - val_loss: 0.8537 - val_accuracy: 0.7692
# Epoch 88/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.6830 - accuracy: 0.7496 - val_loss: 0.8353 - val_accuracy: 0.7308
# Epoch 89/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.6480 - accuracy: 0.7693 - val_loss: 0.8347 - val_accuracy: 0.7231
# Epoch 90/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.7005 - accuracy: 0.7376 - val_loss: 0.8167 - val_accuracy: 0.7462
# Epoch 91/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.6380 - accuracy: 0.7796 - val_loss: 0.8161 - val_accuracy: 0.7615
# Epoch 92/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.6610 - accuracy: 0.7693 - val_loss: 0.8230 - val_accuracy: 0.7000
# Epoch 93/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.6871 - accuracy: 0.7513 - val_loss: 0.8445 - val_accuracy: 0.7308
# Epoch 94/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.6920 - accuracy: 0.7436 - val_loss: 0.8147 - val_accuracy: 0.7692
# Epoch 95/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.6711 - accuracy: 0.7564 - val_loss: 0.8291 - val_accuracy: 0.7385
# Epoch 96/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.6678 - accuracy: 0.7710 - val_loss: 0.8474 - val_accuracy: 0.7385
# Epoch 97/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.6387 - accuracy: 0.7736 - val_loss: 0.8189 - val_accuracy: 0.7692
# Epoch 98/100
# 73/73 [==============================] - 0s 3ms/step - loss: 0.6350 - accuracy: 0.7762 - val_loss: 0.8527 - val_accuracy: 0.7308
# Epoch 99/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.6454 - accuracy: 0.7702 - val_loss: 0.8321 - val_accuracy: 0.7462
# Epoch 100/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.6426 - accuracy: 0.7667 - val_loss: 0.8446 - val_accuracy: 0.7231

# %%
evaluate = model.evaluate(x_test, y_test, batch_size=16)

print("Loss={:.6f}, Accuracy={:.6f}".format(evaluate[0],evaluate[1]))
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.7876 - accuracy: 0.7292
# Loss=0.787566, Accuracy=0.729167

# %%
# plot accuracy
plt.figure()
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.grid()
plt.legend(['Training', 'Validation'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Ajrana Model')
plt.savefig('ajrana_accuracy_sd_speech.svg')

# %%
# make prediction for confusion_matrix
import os
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
predict = model.predict(x_test, batch_size=16)
emotions = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprise']

# predicted emotions from the test set
y_pred = np.argmax(predict, 1)
predicted_emo = []
for i in range(0,y_test.shape[0]):
    emo = emotions[y_pred[i]]
    predicted_emo.append(emo)

# get actual emotion
actual_emo = []
y_true = y_test
for i in range(0,y_test.shape[0]):
    emo = emotions[y_true[i]]
    actual_emo.append(emo)

# generate the confusion matrix
cm = confusion_matrix(actual_emo, predicted_emo)
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

index = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprise']
columns = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprise']
cm_df = pd.DataFrame(cm, index, columns)
plt.figure(figsize=(10, 6))
plt.title('Confusion Matrix of Ajrana')
sns.heatmap(cm_df, annot=True)
plt.savefig('ajrana_cm_sd_speech.svg')

# %%
# print unweighted average recall
print("UAR: ", cm.trace()/cm.shape[0])
# Out:
# UAR:  0.711790415466886
