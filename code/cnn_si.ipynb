# %% [markdown]
# Convolutional Neural Network - Speaker Independent

# %%
# import library
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random as rn

# %%
# clone dataset from github
# !git clone https://github.com/miftanurfarid/speech_emotion_recognition/
# Out:
# Cloning into 'speech_emotion_recognition'...
# remote: Enumerating objects: 6970, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 6970 (delta 66), reused 101 (delta 59), pack-reused 6861
# Receiving objects: 100% (6970/6970), 745.22 MiB | 25.55 MiB/s, done.
# Resolving deltas: 100% (386/386), done.
# Checking out files: 100% (5306/5306), done.

# %%
cd speech_emotion_recognition
# Out:
# /content/speech_emotion_recognition/speech_emotion_recognition

# %%
np.random.seed(123)
rn.seed(123)
tf.random.set_seed(123)

# %%
# load feature data
data_path = 'data/song/' # choose song or speech
x_train = np.load(data_path + 'x_train.npy')
x_test  = np.load(data_path + 'x_test.npy')
y_train = np.load(data_path + 'y_train.npy')
y_test  = np.load(data_path + 'y_test.npy')

# reshape x untuk cnn
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)

# %%
earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                             patience=10,
                                             restore_best_weights=True)

checkpointer = tf.keras.callbacks.ModelCheckpoint(
    filepath='/tmp/weights.hdf5', verbose=1, save_best_only=True)

# %%
# function to define model
def model_cnn():
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.BatchNormalization(axis=-1,
              input_shape=(x_train.shape[1], x_train.shape[2])))
    model.add(tf.keras.layers.Conv1D(256, 128, 1, padding='same'))
    model.add(tf.keras.layers.Activation('relu'))
    model.add(tf.keras.layers.MaxPooling1D(2))
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dropout(0.4))
    model.add(tf.keras.layers.Dense(6, activation='softmax'))

    # compile model: set loss, optimizer, metric
    model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                  optimizer=tf.keras.optimizers.Adam(),
                  metrics=['accuracy'])
    return model

# %%
# create the model
model = model_cnn()
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_1 (Batc  (None, 386, 1)           4
#  hNormalization)
#
#  conv1d_1 (Conv1D)           (None, 386, 256)          33024
#
#  activation_1 (Activation)   (None, 386, 256)          0
#
#  max_pooling1d_1 (MaxPooling  (None, 193, 256)         0
#  1D)
#
#  flatten_1 (Flatten)         (None, 49408)             0
#
#  dropout_1 (Dropout)         (None, 49408)             0
#
#  dense_1 (Dense)             (None, 6)                 296454
#
# =================================================================
# Total params: 329,482
# Trainable params: 329,480
# Non-trainable params: 2
# _________________________________________________________________
# None

# %%
# plot model
tf.keras.utils.plot_model(model,'cnn_model_si.pdf',show_shapes=True)

# %%
# train the model
hist = model.fit(x_train, 
                 y_train, 
                 epochs=100, 
                 shuffle=True,
                 #callbacks=earlystop,
                 validation_split=0.1,
                 batch_size=16)
# Out:
# Epoch 1/100
# 47/47 [==============================] - 3s 60ms/step - loss: 1.8504 - accuracy: 0.2473 - val_loss: 2.3258 - val_accuracy: 0.2857
# Epoch 2/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.5674 - accuracy: 0.3378 - val_loss: 1.4890 - val_accuracy: 0.4167
# Epoch 3/100
# 47/47 [==============================] - 3s 56ms/step - loss: 1.4492 - accuracy: 0.4056 - val_loss: 1.4877 - val_accuracy: 0.3214
# Epoch 4/100
# 47/47 [==============================] - 3s 55ms/step - loss: 1.3101 - accuracy: 0.5013 - val_loss: 1.1646 - val_accuracy: 0.6310
# Epoch 5/100
# 47/47 [==============================] - 3s 56ms/step - loss: 1.1509 - accuracy: 0.5399 - val_loss: 1.1134 - val_accuracy: 0.6429
# Epoch 6/100
# 47/47 [==============================] - 3s 56ms/step - loss: 1.0396 - accuracy: 0.5971 - val_loss: 1.1575 - val_accuracy: 0.6071
# Epoch 7/100
# 47/47 [==============================] - 3s 56ms/step - loss: 1.0531 - accuracy: 0.6144 - val_loss: 0.9347 - val_accuracy: 0.7262
# Epoch 8/100
# 47/47 [==============================] - 3s 55ms/step - loss: 0.8653 - accuracy: 0.6782 - val_loss: 0.9703 - val_accuracy: 0.6667
# Epoch 9/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.8055 - accuracy: 0.7088 - val_loss: 1.2575 - val_accuracy: 0.6310
# Epoch 10/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.7979 - accuracy: 0.6941 - val_loss: 1.1779 - val_accuracy: 0.7143
# Epoch 11/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.7887 - accuracy: 0.7088 - val_loss: 0.9089 - val_accuracy: 0.6905
# Epoch 12/100
# 47/47 [==============================] - 3s 58ms/step - loss: 0.7428 - accuracy: 0.7154 - val_loss: 0.9162 - val_accuracy: 0.7381
# Epoch 13/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.6961 - accuracy: 0.7394 - val_loss: 0.9460 - val_accuracy: 0.6667
# Epoch 14/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.6532 - accuracy: 0.7540 - val_loss: 0.9462 - val_accuracy: 0.7857
# Epoch 15/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.6997 - accuracy: 0.7513 - val_loss: 0.7803 - val_accuracy: 0.7262
# Epoch 16/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.6215 - accuracy: 0.7646 - val_loss: 0.8149 - val_accuracy: 0.7857
# Epoch 17/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.6003 - accuracy: 0.7806 - val_loss: 0.7939 - val_accuracy: 0.7738
# Epoch 18/100
# 47/47 [==============================] - 3s 55ms/step - loss: 0.6261 - accuracy: 0.7673 - val_loss: 0.6574 - val_accuracy: 0.8095
# Epoch 19/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.4992 - accuracy: 0.8125 - val_loss: 0.6142 - val_accuracy: 0.8095
# Epoch 20/100
# 47/47 [==============================] - 3s 55ms/step - loss: 0.5471 - accuracy: 0.7886 - val_loss: 1.0030 - val_accuracy: 0.6905
# Epoch 21/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.6880 - accuracy: 0.7566 - val_loss: 0.9682 - val_accuracy: 0.7381
# Epoch 22/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.5403 - accuracy: 0.7952 - val_loss: 0.8262 - val_accuracy: 0.7262
# Epoch 23/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.5175 - accuracy: 0.8152 - val_loss: 1.2149 - val_accuracy: 0.6905
# Epoch 24/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.6013 - accuracy: 0.7872 - val_loss: 0.7135 - val_accuracy: 0.7143
# Epoch 25/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.4654 - accuracy: 0.8191 - val_loss: 0.9356 - val_accuracy: 0.7143
# Epoch 26/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.4499 - accuracy: 0.8418 - val_loss: 0.8245 - val_accuracy: 0.7738
# Epoch 27/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.5221 - accuracy: 0.8098 - val_loss: 0.7238 - val_accuracy: 0.7857
# Epoch 28/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.3955 - accuracy: 0.8484 - val_loss: 0.6663 - val_accuracy: 0.7500
# Epoch 29/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.4354 - accuracy: 0.8311 - val_loss: 0.7765 - val_accuracy: 0.7381
# Epoch 30/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.4402 - accuracy: 0.8231 - val_loss: 0.7777 - val_accuracy: 0.7738
# Epoch 31/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.5308 - accuracy: 0.8032 - val_loss: 0.6892 - val_accuracy: 0.7262
# Epoch 32/100
# 47/47 [==============================] - 3s 55ms/step - loss: 0.4463 - accuracy: 0.8378 - val_loss: 0.8831 - val_accuracy: 0.6667
# Epoch 33/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.4774 - accuracy: 0.8191 - val_loss: 0.8354 - val_accuracy: 0.7976
# Epoch 34/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.4566 - accuracy: 0.8205 - val_loss: 0.8680 - val_accuracy: 0.7143
# Epoch 35/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.5086 - accuracy: 0.8178 - val_loss: 0.8974 - val_accuracy: 0.7857
# Epoch 36/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.4033 - accuracy: 0.8617 - val_loss: 0.9995 - val_accuracy: 0.7738
# Epoch 37/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.3502 - accuracy: 0.8617 - val_loss: 0.7898 - val_accuracy: 0.7619
# Epoch 38/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.3367 - accuracy: 0.8710 - val_loss: 1.2864 - val_accuracy: 0.7262
# Epoch 39/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.4550 - accuracy: 0.8165 - val_loss: 0.8980 - val_accuracy: 0.7857
# Epoch 40/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.4004 - accuracy: 0.8564 - val_loss: 1.1598 - val_accuracy: 0.7619
# Epoch 41/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.4016 - accuracy: 0.8311 - val_loss: 0.9006 - val_accuracy: 0.7500
# Epoch 42/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.3747 - accuracy: 0.8657 - val_loss: 0.7334 - val_accuracy: 0.7857
# Epoch 43/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.3772 - accuracy: 0.8630 - val_loss: 0.8311 - val_accuracy: 0.7619
# Epoch 44/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.3738 - accuracy: 0.8497 - val_loss: 0.6623 - val_accuracy: 0.8214
# Epoch 45/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.3151 - accuracy: 0.8763 - val_loss: 0.8259 - val_accuracy: 0.7738
# Epoch 46/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.3052 - accuracy: 0.8870 - val_loss: 0.7737 - val_accuracy: 0.8095
# Epoch 47/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.3792 - accuracy: 0.8670 - val_loss: 0.7636 - val_accuracy: 0.7976
# Epoch 48/100
# 47/47 [==============================] - 3s 55ms/step - loss: 0.4040 - accuracy: 0.8537 - val_loss: 1.0513 - val_accuracy: 0.6667
# Epoch 49/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.3933 - accuracy: 0.8497 - val_loss: 0.8897 - val_accuracy: 0.8214
# Epoch 50/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.3710 - accuracy: 0.8577 - val_loss: 0.8874 - val_accuracy: 0.7738
# Epoch 51/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.2793 - accuracy: 0.8910 - val_loss: 0.9821 - val_accuracy: 0.7976
# Epoch 52/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.2691 - accuracy: 0.9016 - val_loss: 0.8457 - val_accuracy: 0.7738
# Epoch 53/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.2901 - accuracy: 0.8830 - val_loss: 0.7601 - val_accuracy: 0.7738
# Epoch 54/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.2664 - accuracy: 0.9056 - val_loss: 1.1495 - val_accuracy: 0.6667
# Epoch 55/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.3974 - accuracy: 0.8604 - val_loss: 0.7265 - val_accuracy: 0.7619
# Epoch 56/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.3444 - accuracy: 0.8684 - val_loss: 1.0631 - val_accuracy: 0.7738
# Epoch 57/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.3389 - accuracy: 0.8910 - val_loss: 0.9880 - val_accuracy: 0.7381
# Epoch 58/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.3164 - accuracy: 0.8723 - val_loss: 0.7232 - val_accuracy: 0.8095
# Epoch 59/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.3202 - accuracy: 0.8856 - val_loss: 0.8379 - val_accuracy: 0.7857
# Epoch 60/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.3187 - accuracy: 0.8910 - val_loss: 1.1997 - val_accuracy: 0.7381
# Epoch 61/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.3111 - accuracy: 0.8949 - val_loss: 0.9552 - val_accuracy: 0.7500
# Epoch 62/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.2921 - accuracy: 0.9029 - val_loss: 0.7609 - val_accuracy: 0.7976
# Epoch 63/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.3323 - accuracy: 0.8684 - val_loss: 1.2173 - val_accuracy: 0.7381
# Epoch 64/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.3117 - accuracy: 0.8723 - val_loss: 1.8184 - val_accuracy: 0.6786
# Epoch 65/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.4343 - accuracy: 0.8537 - val_loss: 0.7376 - val_accuracy: 0.8095
# Epoch 66/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.2570 - accuracy: 0.8989 - val_loss: 0.6762 - val_accuracy: 0.8095
# Epoch 67/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.2538 - accuracy: 0.9056 - val_loss: 1.2968 - val_accuracy: 0.7262
# Epoch 68/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.2285 - accuracy: 0.9149 - val_loss: 0.9311 - val_accuracy: 0.7738
# Epoch 69/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.2681 - accuracy: 0.9003 - val_loss: 0.8969 - val_accuracy: 0.7976
# Epoch 70/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.2946 - accuracy: 0.8963 - val_loss: 0.7618 - val_accuracy: 0.7143
# Epoch 71/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.4154 - accuracy: 0.8537 - val_loss: 1.7664 - val_accuracy: 0.6429
# Epoch 72/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.3985 - accuracy: 0.8537 - val_loss: 0.9763 - val_accuracy: 0.7619
# Epoch 73/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.2843 - accuracy: 0.9003 - val_loss: 1.3810 - val_accuracy: 0.7262
# Epoch 74/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.3244 - accuracy: 0.8790 - val_loss: 1.0720 - val_accuracy: 0.7500
# Epoch 75/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.2084 - accuracy: 0.9176 - val_loss: 0.9589 - val_accuracy: 0.7976
# Epoch 76/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.2572 - accuracy: 0.9043 - val_loss: 1.1430 - val_accuracy: 0.7619
# Epoch 77/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.2940 - accuracy: 0.8910 - val_loss: 0.9777 - val_accuracy: 0.7738
# Epoch 78/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.3589 - accuracy: 0.8590 - val_loss: 1.0862 - val_accuracy: 0.7024
# Epoch 79/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.2573 - accuracy: 0.9029 - val_loss: 0.8217 - val_accuracy: 0.7976
# Epoch 80/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.2226 - accuracy: 0.9122 - val_loss: 1.0056 - val_accuracy: 0.7857
# Epoch 81/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.2600 - accuracy: 0.8963 - val_loss: 0.9158 - val_accuracy: 0.7738
# Epoch 82/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.2061 - accuracy: 0.9255 - val_loss: 0.7643 - val_accuracy: 0.7976
# Epoch 83/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.1981 - accuracy: 0.9202 - val_loss: 0.9360 - val_accuracy: 0.7857
# Epoch 84/100
# 47/47 [==============================] - 3s 66ms/step - loss: 0.2119 - accuracy: 0.9176 - val_loss: 0.9465 - val_accuracy: 0.7857
# Epoch 85/100
# 47/47 [==============================] - 4s 76ms/step - loss: 0.1761 - accuracy: 0.9309 - val_loss: 0.9923 - val_accuracy: 0.7619
# Epoch 86/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.2067 - accuracy: 0.9096 - val_loss: 0.9745 - val_accuracy: 0.8095
# Epoch 87/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.2187 - accuracy: 0.9189 - val_loss: 1.1206 - val_accuracy: 0.7381
# Epoch 88/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.2175 - accuracy: 0.9149 - val_loss: 0.9580 - val_accuracy: 0.7976
# Epoch 89/100
# 47/47 [==============================] - 3s 59ms/step - loss: 0.3623 - accuracy: 0.8750 - val_loss: 1.1972 - val_accuracy: 0.7500
# Epoch 90/100
# 47/47 [==============================] - 3s 58ms/step - loss: 0.2511 - accuracy: 0.8923 - val_loss: 0.9608 - val_accuracy: 0.7619
# Epoch 91/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.2000 - accuracy: 0.9242 - val_loss: 0.9243 - val_accuracy: 0.7619
# Epoch 92/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.2137 - accuracy: 0.9215 - val_loss: 1.4923 - val_accuracy: 0.7381
# Epoch 93/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.1999 - accuracy: 0.9242 - val_loss: 1.1000 - val_accuracy: 0.7738
# Epoch 94/100
# 47/47 [==============================] - 3s 56ms/step - loss: 0.2128 - accuracy: 0.9215 - val_loss: 0.8389 - val_accuracy: 0.7976
# Epoch 95/100
# 47/47 [==============================] - 3s 58ms/step - loss: 0.2151 - accuracy: 0.9229 - val_loss: 1.1786 - val_accuracy: 0.7500
# Epoch 96/100
# 47/47 [==============================] - 3s 58ms/step - loss: 0.1853 - accuracy: 0.9242 - val_loss: 1.2664 - val_accuracy: 0.7262
# Epoch 97/100
# 47/47 [==============================] - 3s 58ms/step - loss: 0.2466 - accuracy: 0.9162 - val_loss: 1.1893 - val_accuracy: 0.7381
# Epoch 98/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.3172 - accuracy: 0.8870 - val_loss: 0.9649 - val_accuracy: 0.7738
# Epoch 99/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.2547 - accuracy: 0.9056 - val_loss: 0.9728 - val_accuracy: 0.7619
# Epoch 100/100
# 47/47 [==============================] - 3s 58ms/step - loss: 0.1725 - accuracy: 0.9362 - val_loss: 0.8326 - val_accuracy: 0.7500

# %%
# evaluate the model on test partition
evaluate = model.evaluate(x_test, y_test, batch_size=16)
print("Loss={:.6f}, Accuracy={:.6f}".format(evaluate[0],evaluate[1]))
# Out:
# 11/11 [==============================] - 0s 13ms/step - loss: 1.0617 - accuracy: 0.6875
# Loss=1.061688, Accuracy=0.687500

# %%
# plot accuracy
plt.figure()
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.grid()
plt.legend(['Training', 'Validation'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('CNN Model')
plt.savefig('cnn_accuracy_si.svg')

# %%
# make prediction for confusion_matrix
import os
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
predict = model.predict(x_test, batch_size=16)
emotions=['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful']

# predicted emotions from the test set
y_pred = np.argmax(predict, 1)
predicted_emo = []
for i in range(0,y_test.shape[0]):
    emo = emotions[y_pred[i]]
    predicted_emo.append(emo)

# get actual emotion
actual_emo = []
y_true = y_test
for i in range(0,y_test.shape[0]):
    emo = emotions[y_true[i]]
    actual_emo.append(emo)

# generate the confusion matrix
cm = confusion_matrix(actual_emo, predicted_emo)
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

index = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful']
columns = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful']
cm_df = pd.DataFrame(cm, index, columns)
plt.figure(figsize=(10, 6))
plt.title('Confusion Matrix of CNN')
sns.heatmap(cm_df, annot=True)
plt.savefig('cnn_cm_si.svg')

# %%
# print unweighted average recall
print("UAR: ", cm.trace()/cm.shape[0])
# Out:
# UAR:  0.6979166666666666
