# %% [markdown]
# DNN Ajrana - Speaker Independent

# %%
# import library
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random as rn

# %%
# clone dataset from github
# !git clone https://github.com/miftanurfarid/speech_emotion_recognition/
# Out:
# Cloning into 'speech_emotion_recognition'...
# remote: Enumerating objects: 6987, done.
# remote: Counting objects: 100% (126/126), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 6987 (delta 77), reused 116 (delta 67), pack-reused 6861
# Receiving objects: 100% (6987/6987), 745.63 MiB | 25.29 MiB/s, done.
# Resolving deltas: 100% (397/397), done.
# Checking out files: 100% (5322/5322), done.

# %%
cd speech_emotion_recognition
# Out:
# /content/speech_emotion_recognition

# %%
np.random.seed(123)
rn.seed(123)
tf.random.set_seed(123)

# %%
# load feature data
data_path = 'data/song/' # choose song or speech
x_train = np.load(data_path + 'x_train_ajrana.npy')
x_test  = np.load(data_path + 'x_test_ajrana.npy')
y_train = np.load(data_path + 'y_train_ajrana.npy')
y_test  = np.load(data_path + 'y_test_ajrana.npy')

# %%
earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                             patience=10,
                                             restore_best_weights=True)

checkpointer = tf.keras.callbacks.ModelCheckpoint(
    filepath='/tmp/weights.hdf5', verbose=1, save_best_only=True)

# %%
# function to build model
def model_dense():
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.BatchNormalization(axis=-1,
              input_shape=(x_train.shape[1:])))
    model.add(tf.keras.layers.Dense(100, activation='relu'))
    model.add(tf.keras.layers.Dropout(0.2))
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(6, activation='softmax'))

    # compile model: set loss, optimizer, metric
    model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                  optimizer=tf.keras.optimizers.Adam(),
                  metrics=['accuracy'])
    return model

# %%
# create the model
model = model_dense()
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 40)               160
#  ormalization)
#
#  dense (Dense)               (None, 100)               4100
#
#  dropout (Dropout)           (None, 100)               0
#
#  flatten (Flatten)           (None, 100)               0
#
#  dense_1 (Dense)             (None, 6)                 606
#
# =================================================================
# Total params: 4,866
# Trainable params: 4,786
# Non-trainable params: 80
# _________________________________________________________________
# None

# %%
# plot model
tf.keras.utils.plot_model(model,'ajrana_model_si.pdf',show_shapes=True)

# %%
# train the model
hist = model.fit(x_train, 
                 y_train, 
                 epochs=100, 
                 shuffle=True,
                 #callbacks=earlystop,
                 validation_split=0.1,
                 batch_size=16)
# Out:
# Epoch 1/100
# 47/47 [==============================] - 1s 6ms/step - loss: 1.7974 - accuracy: 0.2527 - val_loss: 2.0694 - val_accuracy: 0.3452
# Epoch 2/100
# 47/47 [==============================] - 0s 3ms/step - loss: 1.4162 - accuracy: 0.4415 - val_loss: 1.6298 - val_accuracy: 0.4048
# Epoch 3/100
# 47/47 [==============================] - 0s 3ms/step - loss: 1.1864 - accuracy: 0.5758 - val_loss: 1.3177 - val_accuracy: 0.5476
# Epoch 4/100
# 47/47 [==============================] - 0s 3ms/step - loss: 1.0355 - accuracy: 0.6250 - val_loss: 1.1146 - val_accuracy: 0.5595
# Epoch 5/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.9253 - accuracy: 0.6755 - val_loss: 0.9485 - val_accuracy: 0.6190
# Epoch 6/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.8367 - accuracy: 0.7168 - val_loss: 0.8579 - val_accuracy: 0.6667
# Epoch 7/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.7559 - accuracy: 0.7327 - val_loss: 0.7637 - val_accuracy: 0.7143
# Epoch 8/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.7017 - accuracy: 0.7673 - val_loss: 0.7357 - val_accuracy: 0.7500
# Epoch 9/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6915 - accuracy: 0.7580 - val_loss: 0.6823 - val_accuracy: 0.7500
# Epoch 10/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.6297 - accuracy: 0.7806 - val_loss: 0.6885 - val_accuracy: 0.7262
# Epoch 11/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5920 - accuracy: 0.8045 - val_loss: 0.6843 - val_accuracy: 0.7619
# Epoch 12/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.5856 - accuracy: 0.7912 - val_loss: 0.6677 - val_accuracy: 0.7738
# Epoch 13/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.5409 - accuracy: 0.8085 - val_loss: 0.6449 - val_accuracy: 0.7619
# Epoch 14/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.5382 - accuracy: 0.8112 - val_loss: 0.6218 - val_accuracy: 0.7619
# Epoch 15/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5202 - accuracy: 0.8178 - val_loss: 0.5976 - val_accuracy: 0.7619
# Epoch 16/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4812 - accuracy: 0.8324 - val_loss: 0.5970 - val_accuracy: 0.7619
# Epoch 17/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4989 - accuracy: 0.8245 - val_loss: 0.6162 - val_accuracy: 0.7976
# Epoch 18/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4504 - accuracy: 0.8524 - val_loss: 0.5695 - val_accuracy: 0.7857
# Epoch 19/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4402 - accuracy: 0.8524 - val_loss: 0.6217 - val_accuracy: 0.7976
# Epoch 20/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4332 - accuracy: 0.8657 - val_loss: 0.5699 - val_accuracy: 0.7976
# Epoch 21/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4396 - accuracy: 0.8378 - val_loss: 0.6026 - val_accuracy: 0.7857
# Epoch 22/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4374 - accuracy: 0.8444 - val_loss: 0.6160 - val_accuracy: 0.7976
# Epoch 23/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4191 - accuracy: 0.8471 - val_loss: 0.5920 - val_accuracy: 0.7738
# Epoch 24/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4047 - accuracy: 0.8684 - val_loss: 0.5747 - val_accuracy: 0.7857
# Epoch 25/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4035 - accuracy: 0.8537 - val_loss: 0.6127 - val_accuracy: 0.7857
# Epoch 26/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3742 - accuracy: 0.8763 - val_loss: 0.5989 - val_accuracy: 0.7738
# Epoch 27/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3945 - accuracy: 0.8684 - val_loss: 0.6208 - val_accuracy: 0.7738
# Epoch 28/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3665 - accuracy: 0.8684 - val_loss: 0.6150 - val_accuracy: 0.7619
# Epoch 29/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4015 - accuracy: 0.8577 - val_loss: 0.5568 - val_accuracy: 0.7976
# Epoch 30/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3634 - accuracy: 0.8777 - val_loss: 0.6080 - val_accuracy: 0.7857
# Epoch 31/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3494 - accuracy: 0.8710 - val_loss: 0.5760 - val_accuracy: 0.7857
# Epoch 32/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3256 - accuracy: 0.8830 - val_loss: 0.5900 - val_accuracy: 0.7976
# Epoch 33/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3439 - accuracy: 0.8763 - val_loss: 0.5592 - val_accuracy: 0.7976
# Epoch 34/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3314 - accuracy: 0.8936 - val_loss: 0.6482 - val_accuracy: 0.7262
# Epoch 35/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3209 - accuracy: 0.8896 - val_loss: 0.5835 - val_accuracy: 0.7738
# Epoch 36/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3505 - accuracy: 0.8657 - val_loss: 0.6162 - val_accuracy: 0.7738
# Epoch 37/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3417 - accuracy: 0.8816 - val_loss: 0.6046 - val_accuracy: 0.7738
# Epoch 38/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3239 - accuracy: 0.8750 - val_loss: 0.5915 - val_accuracy: 0.7738
# Epoch 39/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3435 - accuracy: 0.8816 - val_loss: 0.6119 - val_accuracy: 0.7857
# Epoch 40/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3155 - accuracy: 0.8870 - val_loss: 0.6128 - val_accuracy: 0.7976
# Epoch 41/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2848 - accuracy: 0.9016 - val_loss: 0.5937 - val_accuracy: 0.7857
# Epoch 42/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3477 - accuracy: 0.8723 - val_loss: 0.6347 - val_accuracy: 0.7738
# Epoch 43/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2762 - accuracy: 0.9003 - val_loss: 0.6047 - val_accuracy: 0.7619
# Epoch 44/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2986 - accuracy: 0.8989 - val_loss: 0.6085 - val_accuracy: 0.7619
# Epoch 45/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2899 - accuracy: 0.9016 - val_loss: 0.6590 - val_accuracy: 0.7500
# Epoch 46/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2953 - accuracy: 0.9003 - val_loss: 0.5982 - val_accuracy: 0.7738
# Epoch 47/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2557 - accuracy: 0.9176 - val_loss: 0.6645 - val_accuracy: 0.7381
# Epoch 48/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2924 - accuracy: 0.8923 - val_loss: 0.5913 - val_accuracy: 0.7619
# Epoch 49/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2490 - accuracy: 0.9082 - val_loss: 0.6400 - val_accuracy: 0.7738
# Epoch 50/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2870 - accuracy: 0.8963 - val_loss: 0.7150 - val_accuracy: 0.7262
# Epoch 51/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2640 - accuracy: 0.9082 - val_loss: 0.6213 - val_accuracy: 0.7857
# Epoch 52/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.2667 - accuracy: 0.9056 - val_loss: 0.7195 - val_accuracy: 0.7500
# Epoch 53/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2319 - accuracy: 0.9043 - val_loss: 0.7825 - val_accuracy: 0.7500
# Epoch 54/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2991 - accuracy: 0.8843 - val_loss: 0.6939 - val_accuracy: 0.7500
# Epoch 55/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2135 - accuracy: 0.9402 - val_loss: 0.6226 - val_accuracy: 0.7738
# Epoch 56/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.2416 - accuracy: 0.9162 - val_loss: 0.6966 - val_accuracy: 0.7619
# Epoch 57/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2397 - accuracy: 0.9176 - val_loss: 0.6907 - val_accuracy: 0.7619
# Epoch 58/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.2707 - accuracy: 0.9029 - val_loss: 0.6772 - val_accuracy: 0.7500
# Epoch 59/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2406 - accuracy: 0.9215 - val_loss: 0.6958 - val_accuracy: 0.7381
# Epoch 60/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2743 - accuracy: 0.8989 - val_loss: 0.7739 - val_accuracy: 0.7143
# Epoch 61/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2464 - accuracy: 0.9056 - val_loss: 0.6972 - val_accuracy: 0.7619
# Epoch 62/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2520 - accuracy: 0.9069 - val_loss: 0.7647 - val_accuracy: 0.7619
# Epoch 63/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2350 - accuracy: 0.9176 - val_loss: 0.7311 - val_accuracy: 0.7619
# Epoch 64/100
# 47/47 [==============================] - 0s 4ms/step - loss: 0.2306 - accuracy: 0.9229 - val_loss: 0.7012 - val_accuracy: 0.7500
# Epoch 65/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.2595 - accuracy: 0.9202 - val_loss: 0.7346 - val_accuracy: 0.7381
# Epoch 66/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2172 - accuracy: 0.9149 - val_loss: 0.7222 - val_accuracy: 0.7500
# Epoch 67/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.2849 - accuracy: 0.9016 - val_loss: 0.7370 - val_accuracy: 0.7262
# Epoch 68/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.2232 - accuracy: 0.9202 - val_loss: 0.8512 - val_accuracy: 0.7024
# Epoch 69/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2169 - accuracy: 0.9309 - val_loss: 0.7433 - val_accuracy: 0.7500
# Epoch 70/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2087 - accuracy: 0.9255 - val_loss: 0.6733 - val_accuracy: 0.7619
# Epoch 71/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.2443 - accuracy: 0.9082 - val_loss: 0.8288 - val_accuracy: 0.7262
# Epoch 72/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2131 - accuracy: 0.9242 - val_loss: 0.6966 - val_accuracy: 0.7976
# Epoch 73/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2133 - accuracy: 0.9242 - val_loss: 0.8058 - val_accuracy: 0.7381
# Epoch 74/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.2165 - accuracy: 0.9215 - val_loss: 0.7939 - val_accuracy: 0.7143
# Epoch 75/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2220 - accuracy: 0.9202 - val_loss: 0.7716 - val_accuracy: 0.7262
# Epoch 76/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2280 - accuracy: 0.9176 - val_loss: 0.8174 - val_accuracy: 0.7619
# Epoch 77/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.2200 - accuracy: 0.9162 - val_loss: 0.7526 - val_accuracy: 0.7381
# Epoch 78/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2409 - accuracy: 0.9069 - val_loss: 0.7476 - val_accuracy: 0.7381
# Epoch 79/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.1924 - accuracy: 0.9189 - val_loss: 0.8196 - val_accuracy: 0.7500
# Epoch 80/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.2378 - accuracy: 0.9109 - val_loss: 0.6710 - val_accuracy: 0.7619
# Epoch 81/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2106 - accuracy: 0.9215 - val_loss: 0.7625 - val_accuracy: 0.7500
# Epoch 82/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.2047 - accuracy: 0.9189 - val_loss: 0.6947 - val_accuracy: 0.7619
# Epoch 83/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1815 - accuracy: 0.9428 - val_loss: 0.7626 - val_accuracy: 0.7619
# Epoch 84/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.1849 - accuracy: 0.9335 - val_loss: 0.7286 - val_accuracy: 0.7500
# Epoch 85/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2025 - accuracy: 0.9229 - val_loss: 0.7672 - val_accuracy: 0.7381
# Epoch 86/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2136 - accuracy: 0.9255 - val_loss: 0.7851 - val_accuracy: 0.7500
# Epoch 87/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.2238 - accuracy: 0.9295 - val_loss: 0.7394 - val_accuracy: 0.7619
# Epoch 88/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2148 - accuracy: 0.9242 - val_loss: 0.8251 - val_accuracy: 0.7500
# Epoch 89/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.1988 - accuracy: 0.9309 - val_loss: 0.8113 - val_accuracy: 0.7500
# Epoch 90/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.1668 - accuracy: 0.9441 - val_loss: 0.8615 - val_accuracy: 0.7262
# Epoch 91/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.1843 - accuracy: 0.9388 - val_loss: 0.7825 - val_accuracy: 0.7381
# Epoch 92/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.1786 - accuracy: 0.9441 - val_loss: 0.8406 - val_accuracy: 0.7381
# Epoch 93/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.1899 - accuracy: 0.9269 - val_loss: 0.8428 - val_accuracy: 0.7619
# Epoch 94/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.1757 - accuracy: 0.9348 - val_loss: 0.7569 - val_accuracy: 0.7619
# Epoch 95/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.1745 - accuracy: 0.9388 - val_loss: 0.9499 - val_accuracy: 0.7024
# Epoch 96/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.1949 - accuracy: 0.9348 - val_loss: 0.7625 - val_accuracy: 0.7381
# Epoch 97/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.1872 - accuracy: 0.9295 - val_loss: 0.7535 - val_accuracy: 0.7381
# Epoch 98/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1847 - accuracy: 0.9322 - val_loss: 0.8051 - val_accuracy: 0.7262
# Epoch 99/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2104 - accuracy: 0.9242 - val_loss: 0.8408 - val_accuracy: 0.7024
# Epoch 100/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.2035 - accuracy: 0.9282 - val_loss: 0.7991 - val_accuracy: 0.7381

# %%
evaluate = model.evaluate(x_test, y_test, batch_size=16)

print("Loss={:.6f}, Accuracy={:.6f}".format(evaluate[0],evaluate[1]))
# Out:
# 11/11 [==============================] - 0s 2ms/step - loss: 1.2413 - accuracy: 0.6193
# Loss=1.241338, Accuracy=0.619318

# %%
# plot accuracy
plt.figure()
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.grid()
plt.legend(['Training', 'Validation'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Ajrana Model')
plt.savefig('ajrana_accuracy_si.svg')

# %%
# make prediction for confusion_matrix
import os
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
predict = model.predict(x_test, batch_size=16)
emotions=['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful']

# predicted emotions from the test set
y_pred = np.argmax(predict, 1)
predicted_emo = []
for i in range(0,y_test.shape[0]):
    emo = emotions[y_pred[i]]
    predicted_emo.append(emo)

# get actual emotion
actual_emo = []
y_true = y_test
for i in range(0,y_test.shape[0]):
    emo = emotions[y_true[i]]
    actual_emo.append(emo)

# generate the confusion matrix
cm = confusion_matrix(actual_emo, predicted_emo)
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

index = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful']
columns = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful']
cm_df = pd.DataFrame(cm, index, columns)
plt.figure(figsize=(10, 6))
plt.title('Confusion Matrix of Ajrana')
sns.heatmap(cm_df, annot=True)
plt.savefig('ajrana_cm_si.svg')

# %%
# print unweighted average recall
print("UAR: ", cm.trace()/cm.shape[0])
# Out:
# UAR:  0.5989583333333334
